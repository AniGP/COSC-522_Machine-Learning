# %% [markdown]
# ## COSC522: Final Project - Catifier
# ### Cameron Adkins, Purnachandra Anirudh Gajjala, Gabriel Abeyie

# %%
# Numpy.
import numpy as np
from numpy.lib.stride_tricks import sliding_window_view

# Need plots.
import matplotlib.pyplot as plt

# Pandas.
import pandas as pd

# Machine learning toolkit.
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import *
from sklearn.preprocessing import Normalizer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, accuracy_score

# Scipy for fft's and the like.
import scipy as sc
import scipy.io.wavfile as wavfile
from scipy import signal
from scipy.fftpack import fft, fftfreq
from scipy import stats

# Seaborn for plots.
import seaborn as sns

# IPython for basic visual output types.
import IPython

# Imbalanced learn for rebalancing.
from imblearn.over_sampling import SMOTE

# Standard Python libs.
import os
import glob
import csv
import xml.etree.ElementTree as et
from dataclasses import dataclass

# Pillow.
import PIL as pil
from PIL import ImageDraw

# Tensorflow
#import tensorflow as tf
#from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.datasets import fashion_mnist
#from tensorflow.keras.layers import Dense
#from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.layers import Conv2D, Flatten, Dense, AveragePooling2D, GlobalAveragePooling2D,Dropout
#from tensorflow.keras.applications.resnet import ResNet50
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.preprocessing.image import ImageDataGenerator

# For images
from skimage.color import rgb2gray
import cv2
from scipy import ndimage

# %%
# Utility functions.

def image_load(filename):
    loader = pil.Image.open(filename);
    ret = loader.copy();
    loader.close();
    
    return ret;

def image_resize(image, new_width):
    new_height = int(new_width * (image.height / image.width));
    
    return image.resize((new_width, new_height), pil.Image.Resampling.LANCZOS);

def trimap_to_mask(trimap, include_border = True):
    trimap_data = trimap.getdata();
    
    mask_data = np.zeros((trimap.height, trimap.width), dtype=np.uint8);
    
    for x in range(0, trimap.width):
        for y in range(0, trimap.height):
            idx = x + (y * trimap.width);
            tri = trimap_data[idx];
            
            if (tri == 1 or (include_border == True and tri == 3)):
                mask_data[y, x] = 255;
            else:
                mask_data[y, x] = 0;
                
    mask = pil.Image.fromarray(mask_data);
    
    return mask;

# %%
# Class definitions.

@dataclass
class Point:
    x: int;
    y: int;

@dataclass
class BoundingBox:
    ll: Point;
    lr: Point;
    ul: Point;
    ur: Point;

class CatBreedSample:
    def __init__(self, label, image_file, mask_file = None, bb_file = None):
        self.label = label;
        
        self.image_file = image_file;
        self.mask_file  = mask_file;
        self.bb_file    = bb_file;
        
        # Load the image
        self.image = image_load(self.image_file);

        # Composite if a mask is available.
        if (self.mask_file):
            self.mask = trimap_to_mask(image_load(self.mask_file), False);
            
            background = pil.Image.new("RGB", self.mask.size, 0);
            self.masked_image = pil.Image.composite(self.image, background, self.mask);
        else:
            self.mask = None;
            self.masked_image = None;
            
        # Get a bounding box.
        if (self.bb_file):
            tree = et.parse(self.bb_file);
            root = tree.getroot();

            xmin = int(root.findall("./object/bndbox/xmin")[0].text);
            xmax = int(root.findall("./object/bndbox/xmax")[0].text);
            ymin = int(root.findall("./object/bndbox/ymin")[0].text);
            ymax = int(root.findall("./object/bndbox/ymax")[0].text);

            self.bb = BoundingBox(0, 0, 0, 0);
            
            self.bb.ll = Point(xmin, ymin);
            self.bb.lr = Point(xmax, ymin);
            self.bb.ul = Point(xmin, ymax);
            self.bb.ur = Point(xmax, ymax);
            
            if (self.masked_image):
                self.bounded_image = self.masked_image.crop((xmin, ymin, xmax, ymax));
            else:
                self.bounded_image = self.image.crop((xmin, ymin, xmax, ymax));

        else:
            self.bb = None;
            self.bounded_image = None;

        self.image = image_resize(self.image, 256);
        self.masked_image = image_resize(self.masked_image, 256);
        self.bounded_image = image_resize(self.bounded_image, 256);

    def display(self):
        print("Image:", self.image_file);
        print("Label:", self.label);
        
        display(self.image);
        
        if (self.mask):
            display(self.masked_image);
            
        if (self.bb):
            display(self.bounded_image);
            
    def features(self):
        fv = [];
        
        # Determine eye positions.
        
        # Determine ear positions.
        # We just estimate by starting at corners of the region segmentation and working
        # our way towards the center. The first non-black pixel is our x/y.
        region_segmentation = self.segmentation_regionbased();
        
        #Left
        
        left_ear = (0, 0);

        #print(len(region_segmentation), len(region_segmentation[0]))
        #print(seg_data[0], seg_data[1], seg_data[2], seg_data[3]);

        for y in range(0, int(len(region_segmentation) / 2)):
            for x in range(0, int(len(region_segmentation[0]) / 2)):
                #print(region_segmentation[y, x], end = " ")
                if (region_segmentation[x, y] != 0):
                    #print(x, y, "=", region_segmentation[y, x]);
                    left_ear = (y, x);
                    break;
                    
            if (left_ear != (0, 0)):
                break;

        #print(left_ear);
                
        #Right
    
        right_ear = (0, 0);

        for y in range(0, int(len(region_segmentation) / 2)):
            for x in reversed(range(int(len(region_segmentation[0]) / 2), int(len(region_segmentation[0])))):
                #print(region_segmentation[y, x], end = " ")
                if (region_segmentation[y, x] != 0):
                    #region_segmentation[y, x] = 0.5;
                    right_ear = (x, y);
                    break;
                    
            if (right_ear != (0, 0)):
                break;

        #print(right_ear);
    
        #plt.imshow(region_segmentation, cmap='gray');
        
        #draw = ImageDraw.Draw(self.bounded_image);
        #ellipse = ((left_ear[0] - 2, left_ear[1] - 2, left_ear[0] + 2, left_ear[1] + 2));
        #draw.ellipse(ellipse, fill = "red", outline = "red");
        #ellipse = ((right_ear[0] - 2, right_ear[1] - 2, right_ear[0] + 2, right_ear[1] + 2));
        #draw.ellipse(ellipse, fill = "red", outline = "red");
        
        fv.append(right_ear[0] - left_ear[0]);
        fv.append(right_ear[1] - left_ear[1]);
        
        # Bin the colors that make up this image.
        #region_segmentation = self.segmentation_colorclustering();
        #unique, counts = np.unique(region_segmentation, return_counts = True);
        
        #unique_colors = dict(zip(unique, counts));
        
        #counts = counts[1:];
        #_, counts = np.unique(counts, return_counts = True);
        
        cv2image = np.array(self.masked_image);
        
        channels = cv2.split(cv2image);
        
        for i in range(0, 3):
            hist = cv2.calcHist([channels[i]], [0], None, [5], [0, 255]);
            for val in hist:
                fv.append(int(val));
            #print(hist);
        #plt.figure();
        #plt.plot(hist);
        #plt.xlim([0, 256])
        #plt.ylim([0, 1200])
        #region_segmentation
        
        #print(unique);

        return fv;
    
    def segmentation_regionbased(self):
        gray = rgb2gray(np.array(self.bounded_image));
        #plt.imshow(gray, cmap = 'gray')
        
        gray_r = gray.reshape(gray.shape[0]*gray.shape[1])
        
        for i in range(gray_r.shape[0]):
            
            if gray_r[i] > gray_r.mean():
                
                gray_r[i] = 1

            else:
                
                gray_r[i] = 0

        gray = gray_r.reshape(gray.shape[0],gray.shape[1])
        #plt.figure();
        #plt.imshow(gray, cmap='gray')
        
        return gray;
        
        # The darker region (black) represents the background and the brighter (white) region is the foreground. We can define multiple thresholds as well to detect multiple objects:

        # gray_r = gray.reshape(gray.shape[0]*gray.shape[1])

        #for i in range(gray_r.shape[0]):
            #if gray_r[i] > gray_r.mean():
                #gray_r[i] = 3
            #elif gray_r[i] > 0.5:
                #gray_r[i] = 2
            #elif gray_r[i] > 0.25:
                #gray_r[i] = 1
            #else:
                #gray_r[i] = 0

        #gray = gray_r.reshape(gray.shape[0],gray.shape[1])
        #plt.imshow(gray, cmap='gray')
            
    def segmentation_edgebased(self):
        gray = rgb2gray(np.array(self.bounded_image));
                
        #plt.figure();
        #plt.imshow(gray, cmap='gray');

        # defining the sobel filters

        # [
        #  [ 1  2  1]
        #  [ 0  0  0]
        #  [-1 -2 -1]
        # ] 
        # is a kernel for detecting horizontal edges

        # [
        #  [-1  0  1]
        #  [-2  0  2]
        #  [-1  0  1]
        # ] 
        # is a kernel for detecting vertical edges

        sobel_horizontal = np.array([np.array([1, 2, 1]), np.array([0, 0, 0]), np.array([-1, -2, -1])])
        print('Kernel for detecting horizontal edges:\n', sobel_horizontal)

        sobel_vertical = np.array([np.array([-1, 0, 1]), np.array([-2, 0, 2]), np.array([-1, 0, 1])])
        print('Kernel for detecting vertical edges:\n', sobel_vertical)

        out_h = ndimage.convolve(gray, sobel_horizontal, mode='reflect')
        out_v = ndimage.convolve(gray, sobel_vertical, mode='reflect')

        # here mode determines how the input array is extended when the filter overlaps a border.

        plt.figure();
        plt.imshow(out_h, cmap='gray')
        plt.imshow(out_v, cmap='gray')

        # Here, we are able to identify the horizontal as well as the vertical edges. There is one more type of filter that can detect both horizontal and vertical edges at the same time. This is called the laplace operator:

        # [
        #  [1  1  1]
        #  [1 -8  1]
        #  [1  1  1]
        # ]

        kernel_laplace = np.array([np.array([1, 1, 1]), np.array([1, -8, 1]), np.array([1, 1, 1])])
        print("Laplacian kernel:\n", kernel_laplace)
        
        out_l = ndimage.convolve(gray, kernel_laplace, mode='reflect')
        plt.figure();
        plt.imshow(out_l, cmap='gray')

    def segmentation_colorclustering(self):
        # According to wikipedia the R, G, and B components of an object’s color in a digital image are all correlated with the amount of light hitting the object, 
        # and therefore with each other, image descriptions in terms of those components make object discrimination difficult. 
        # Descriptions in terms of hue/lightness/chroma or hue/lightness/saturation are often more relevant. So, we need to convert our image from RGB Colours Space to HSV to work ahead.

        cv2img = np.array(self.masked_image);

        vectorized = np.float32(cv2img.reshape((-1,3)))
        vectorized.shape

        criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 20, 1.0)

        K = 8
        attempts=10
        ret, label, center = cv2.kmeans(vectorized, K, None, criteria, attempts, cv2.KMEANS_PP_CENTERS)

        center = np.uint8(center)
        res = center[label.flatten()]
        result_image = res.reshape((cv2img.shape))

        # result_image is the output result. Lets see how the image looks after k-means clustering

        #figure_size = 15
        #plt.figure(figsize=(figure_size, figure_size))
        #plt.subplot(2,3,1),plt.imshow(cv2img)
        #plt.title('Original Image'), plt.xticks([]), plt.yticks([])
        #plt.subplot(2,3,2),plt.imshow(result_image)
        #plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
        #plt.show()
        
        return result_image;
    
    def haarcascade_classifier(self):
        cv2img  = np.array(self.image);
        cv2gray = cv2.cvtColor(cv2img, cv2.COLOR_RGB2GRAY);
        
        cascade = cv2.CascadeClassifier("pretrained/haarcascade_frontalcatface.xml");
        
        bounding_rects = cascade.detectMultiScale(cv2gray, scaleFactor = 1.3, minNeighbors = 1, minSize = (25, 25));
        
        print(bounding_rects);
        
        for (x, y, w, h) in bounding_rects:
            cv2.rectangle(cv2gray, (x, y), (x + w, y + h), (0, 0, 255), 2);
            
        plt.figure();
        plt.imshow(cv2gray, cmap='gray');
        
    def contours(self):
        #region_segmentation = self.segmentation_regionbased();
        region_segmentation = np.array(self.bounded_image);
        region_segmentation = cv2.cvtColor(region_segmentation, cv2.COLOR_RGB2GRAY)
        
        
        ret, threshold = cv2.threshold(region_segmentation, 16, 255, cv2.THRESH_BINARY);
        image, contours, hierarchy = cv2.findContours(threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE);

        
        cv2.drawContours(threshold, contours, -1, (0, 255, 0), 3);
        
        approx = cv2.approxPolyDP(contours[1], 0.01 * cv2.arcLength(contours[1], True), True)
        
        print(approx);
        
        plt.figure();
        plt.imshow(threshold);
        
        #i = 0;

        #for contour in contours:
        #    # here we are ignoring first counter because 
        #    # findcontour function detects whole image as shape
        #    if i == 0:
        #        i = 1
        #        continue
        #
        #    # cv2.approxPloyDP() function to approximate the shape
        #    #approx = cv2.approxPolyDP(contour, 0.01 * cv2.arcLength(contour, True), True)
        #    
        #    print(contour)
        #    
        #    # using drawContours() function
        #    cv2.drawContours(region_segmentation, [contour], 0, (0, 0, 255), 5)
        
        #plt.figure();
        #plt.imshow(region_segmentation);

# %%
#test_sample = CatBreedSample(
#    "Abyssinian",
#    "/home/cva/catifier/training_data/Abyssinian/Abyssinian_115.jpg",
#    "/home/cva/catifier/training_data/Abyssinian/Abyssinian_115_mask.png",
#    "/home/cva/catifier/training_data/Abyssinian/Abyssinian_115_bb.xml"
#)

#test_sample.segmentation_regionbased();
#test_sample.segmentation_edgebased();
#test_sample.segmentation_colorclustering();
#test_sample.haarcascade_classifier();
#test_sample.contours();

#fv = test_sample.features();

#test_sample.display();

# %%
# Load everything.
def load_samples(samples_dir):
    class_dirs = glob.glob(samples_dir + "/*")

    samples = [];

    for class_dir in class_dirs:
        label = os.path.basename(class_dir);
        class_dir_glob = glob.glob(class_dir + "/*.jpg");
    
        print("Reading files for label '" + label + "'");
    
        for sample_image in class_dir_glob:
            basename  = os.path.splitext(sample_image)[0];
            mask_file = basename + "_mask.png";
            bb_file   = basename + "_bb.xml";
            
            if (not os.path.exists(mask_file)):
                mask_file = None;
                
            if (not os.path.exists(bb_file)):
                continue;
                #bb_file = None;
            
            print(
                len(samples), 
                ":", 
                os.path.basename(sample_image), 
                "\t(mask:", 
                (mask_file != None), 
                "| bb:", 
                (bb_file != None), 
                ")"
            );
            
            sample = CatBreedSample(label, sample_image, mask_file, bb_file);
            samples.append(sample);

    return samples;

PWD = os.getcwd();
TRAINING_DATA = PWD + "/training_data";
samples = load_samples(TRAINING_DATA);
# Out:
# Reading files for label 'Abyssinian'
# 0 : Abyssinian_117.jpg 	(mask: True | bb: True )
# 1 : Abyssinian_103.jpg 	(mask: True | bb: True )
# 2 : Abyssinian_155.jpg 	(mask: True | bb: True )
# 3 : Abyssinian_143.jpg 	(mask: True | bb: True )
# 4 : Abyssinian_150.jpg 	(mask: True | bb: True )
# 5 : Abyssinian_165.jpg 	(mask: True | bb: True )
# 6 : Abyssinian_16.jpg 	(mask: True | bb: True )
# 7 : Abyssinian_118.jpg 	(mask: True | bb: True )
# 8 : Abyssinian_183.jpg 	(mask: True | bb: True )
# 9 : Abyssinian_123.jpg 	(mask: True | bb: True )
# 10 : Abyssinian_159.jpg 	(mask: True | bb: True )
# 11 : Abyssinian_158.jpg 	(mask: True | bb: True )
# 12 : Abyssinian_142.jpg 	(mask: True | bb: True )
# 13 : Abyssinian_114.jpg 	(mask: True | bb: True )
# 14 : Abyssinian_125.jpg 	(mask: True | bb: True )
# 15 : Abyssinian_140.jpg 	(mask: True | bb: True )
# 16 : Abyssinian_138.jpg 	(mask: True | bb: True )
# 17 : Abyssinian_181.jpg 	(mask: True | bb: True )
# 18 : Abyssinian_127.jpg 	(mask: True | bb: True )
# 19 : Abyssinian_161.jpg 	(mask: True | bb: True )
# 20 : Abyssinian_122.jpg 	(mask: True | bb: True )
# 21 : Abyssinian_174.jpg 	(mask: True | bb: True )
# 22 : Abyssinian_149.jpg 	(mask: True | bb: True )
# 23 : Abyssinian_136.jpg 	(mask: True | bb: True )
# 24 : Abyssinian_121.jpg 	(mask: True | bb: True )
# 25 : Abyssinian_141.jpg 	(mask: True | bb: True )
# 26 : Abyssinian_13.jpg 	(mask: True | bb: True )
# 27 : Abyssinian_102.jpg 	(mask: True | bb: True )
# 28 : Abyssinian_145.jpg 	(mask: True | bb: True )
# 29 : Abyssinian_133.jpg 	(mask: True | bb: True )
# 30 : Abyssinian_176.jpg 	(mask: True | bb: True )
# 31 : Abyssinian_18.jpg 	(mask: True | bb: True )
# 32 : Abyssinian_192.jpg 	(mask: True | bb: True )
# 33 : Abyssinian_167.jpg 	(mask: True | bb: True )
# 34 : Abyssinian_106.jpg 	(mask: True | bb: True )
# 35 : Abyssinian_119.jpg 	(mask: True | bb: True )
# 36 : Abyssinian_191.jpg 	(mask: True | bb: True )
# 37 : Abyssinian_175.jpg 	(mask: True | bb: True )
# 38 : Abyssinian_14.jpg 	(mask: True | bb: True )
# 39 : Abyssinian_120.jpg 	(mask: True | bb: True )
# 40 : Abyssinian_151.jpg 	(mask: True | bb: True )
# 41 : Abyssinian_109.jpg 	(mask: True | bb: True )
# 42 : Abyssinian_190.jpg 	(mask: True | bb: True )
# 43 : Abyssinian_184.jpg 	(mask: True | bb: True )
# 44 : Abyssinian_11.jpg 	(mask: True | bb: True )
# 45 : Abyssinian_157.jpg 	(mask: True | bb: True )
# 46 : Abyssinian_116.jpg 	(mask: True | bb: True )
# 47 : Abyssinian_182.jpg 	(mask: True | bb: True )
# 48 : Abyssinian_193.jpg 	(mask: True | bb: True )
# 49 : Abyssinian_111.jpg 	(mask: True | bb: True )
# 50 : Abyssinian_195.jpg 	(mask: True | bb: True )
# 51 : Abyssinian_169.jpg 	(mask: True | bb: True )
# 52 : Abyssinian_128.jpg 	(mask: True | bb: True )
# 53 : Abyssinian_10.jpg 	(mask: True | bb: True )
# 54 : Abyssinian_164.jpg 	(mask: True | bb: True )
# 55 : Abyssinian_126.jpg 	(mask: True | bb: True )
# 56 : Abyssinian_179.jpg 	(mask: True | bb: True )
# 57 : Abyssinian_124.jpg 	(mask: True | bb: True )
# 58 : Abyssinian_152.jpg 	(mask: True | bb: True )
# 59 : Abyssinian_146.jpg 	(mask: True | bb: True )
# 60 : Abyssinian_173.jpg 	(mask: True | bb: True )
# 61 : Abyssinian_180.jpg 	(mask: True | bb: True )
# 62 : Abyssinian_160.jpg 	(mask: True | bb: True )
# 63 : Abyssinian_110.jpg 	(mask: True | bb: True )
# 64 : Abyssinian_134.jpg 	(mask: True | bb: True )
# 65 : Abyssinian_130.jpg 	(mask: True | bb: True )
# 66 : Abyssinian_153.jpg 	(mask: True | bb: True )
# 67 : Abyssinian_168.jpg 	(mask: True | bb: True )
# 68 : Abyssinian_197.jpg 	(mask: True | bb: True )
# 69 : Abyssinian_166.jpg 	(mask: True | bb: True )
# 70 : Abyssinian_196.jpg 	(mask: True | bb: True )
# 71 : Abyssinian_107.jpg 	(mask: True | bb: True )
# 72 : Abyssinian_135.jpg 	(mask: True | bb: True )
# 73 : Abyssinian_178.jpg 	(mask: True | bb: True )
# 74 : Abyssinian_185.jpg 	(mask: True | bb: True )
# 75 : Abyssinian_12.jpg 	(mask: True | bb: True )
# 76 : Abyssinian_172.jpg 	(mask: True | bb: True )
# 77 : Abyssinian_115.jpg 	(mask: True | bb: True )
# 78 : Abyssinian_15.jpg 	(mask: True | bb: True )
# 79 : Abyssinian_144.jpg 	(mask: True | bb: True )
# 80 : Abyssinian_19.jpg 	(mask: True | bb: True )
# 81 : Abyssinian_105.jpg 	(mask: True | bb: True )
# 82 : Abyssinian_139.jpg 	(mask: True | bb: True )
# 83 : Abyssinian_129.jpg 	(mask: True | bb: True )
# 84 : Abyssinian_17.jpg 	(mask: True | bb: True )
# 85 : Abyssinian_148.jpg 	(mask: True | bb: True )
# 86 : Abyssinian_154.jpg 	(mask: True | bb: True )
# 87 : Abyssinian_177.jpg 	(mask: True | bb: True )
# 88 : Abyssinian_1.jpg 	(mask: True | bb: True )
# 89 : Abyssinian_132.jpg 	(mask: True | bb: True )
# 90 : Abyssinian_156.jpg 	(mask: True | bb: True )
# 91 : Abyssinian_170.jpg 	(mask: True | bb: True )
# 92 : Abyssinian_131.jpg 	(mask: True | bb: True )
# 93 : Abyssinian_100.jpg 	(mask: True | bb: True )
# 94 : Abyssinian_137.jpg 	(mask: True | bb: True )
# 95 : Abyssinian_112.jpg 	(mask: True | bb: True )
# 96 : Abyssinian_108.jpg 	(mask: True | bb: True )
# 97 : Abyssinian_101.jpg 	(mask: True | bb: True )
# 98 : Abyssinian_113.jpg 	(mask: True | bb: True )
# Reading files for label 'Sphynx'
# 99 : Sphynx_203.jpg 	(mask: True | bb: True )
# 100 : Sphynx_195.jpg 	(mask: True | bb: True )
# 101 : Sphynx_116.jpg 	(mask: True | bb: True )
# 102 : Sphynx_112.jpg 	(mask: True | bb: True )
# 103 : Sphynx_138.jpg 	(mask: True | bb: True )
# 104 : Sphynx_153.jpg 	(mask: True | bb: True )
# 105 : Sphynx_202.jpg 	(mask: True | bb: True )
# 106 : Sphynx_185.jpg 	(mask: True | bb: True )
# 107 : Sphynx_186.jpg 	(mask: True | bb: True )
# 108 : Sphynx_179.jpg 	(mask: True | bb: True )
# 109 : Sphynx_148.jpg 	(mask: True | bb: True )
# 110 : Sphynx_108.jpg 	(mask: True | bb: True )
# 111 : Sphynx_189.jpg 	(mask: True | bb: True )
# 112 : Sphynx_204.jpg 	(mask: True | bb: True )
# 113 : Sphynx_142.jpg 	(mask: True | bb: True )
# 114 : Sphynx_197.jpg 	(mask: True | bb: True )
# 115 : Sphynx_128.jpg 	(mask: True | bb: True )
# 116 : Sphynx_187.jpg 	(mask: True | bb: True )
# 117 : Sphynx_156.jpg 	(mask: True | bb: True )
# 118 : Sphynx_183.jpg 	(mask: True | bb: True )
# 119 : Sphynx_126.jpg 	(mask: True | bb: True )
# 120 : Sphynx_17.jpg 	(mask: True | bb: True )
# 121 : Sphynx_165.jpg 	(mask: True | bb: True )
# 122 : Sphynx_198.jpg 	(mask: True | bb: True )
# 123 : Sphynx_166.jpg 	(mask: True | bb: True )
# 124 : Sphynx_115.jpg 	(mask: True | bb: True )
# 125 : Sphynx_172.jpg 	(mask: True | bb: True )
# 126 : Sphynx_1.jpg 	(mask: True | bb: True )
# 127 : Sphynx_196.jpg 	(mask: True | bb: True )
# 128 : Sphynx_151.jpg 	(mask: True | bb: True )
# 129 : Sphynx_18.jpg 	(mask: True | bb: True )
# 130 : Sphynx_117.jpg 	(mask: True | bb: True )
# 131 : Sphynx_139.jpg 	(mask: True | bb: True )
# 132 : Sphynx_131.jpg 	(mask: True | bb: True )
# 133 : Sphynx_144.jpg 	(mask: True | bb: True )
# 134 : Sphynx_176.jpg 	(mask: True | bb: True )
# 135 : Sphynx_155.jpg 	(mask: True | bb: True )
# 136 : Sphynx_152.jpg 	(mask: True | bb: True )
# 137 : Sphynx_193.jpg 	(mask: True | bb: True )
# 138 : Sphynx_122.jpg 	(mask: True | bb: True )
# 139 : Sphynx_121.jpg 	(mask: True | bb: True )
# 140 : Sphynx_127.jpg 	(mask: True | bb: True )
# 141 : Sphynx_177.jpg 	(mask: True | bb: True )
# 142 : Sphynx_164.jpg 	(mask: True | bb: True )
# 143 : Sphynx_114.jpg 	(mask: True | bb: True )
# 144 : Sphynx_171.jpg 	(mask: True | bb: True )
# 145 : Sphynx_150.jpg 	(mask: True | bb: True )
# 146 : Sphynx_111.jpg 	(mask: True | bb: True )
# 147 : Sphynx_162.jpg 	(mask: True | bb: True )
# 148 : Sphynx_201.jpg 	(mask: True | bb: True )
# 149 : Sphynx_178.jpg 	(mask: True | bb: True )
# 150 : Sphynx_107.jpg 	(mask: True | bb: True )
# 151 : Sphynx_191.jpg 	(mask: True | bb: True )
# 152 : Sphynx_188.jpg 	(mask: True | bb: True )
# 153 : Sphynx_143.jpg 	(mask: True | bb: True )
# 154 : Sphynx_180.jpg 	(mask: True | bb: True )
# 155 : Sphynx_141.jpg 	(mask: True | bb: True )
# 156 : Sphynx_110.jpg 	(mask: True | bb: True )
# 157 : Sphynx_170.jpg 	(mask: True | bb: True )
# 158 : Sphynx_192.jpg 	(mask: True | bb: True )
# 159 : Sphynx_173.jpg 	(mask: True | bb: True )
# 160 : Sphynx_12.jpg 	(mask: True | bb: True )
# 161 : Sphynx_124.jpg 	(mask: True | bb: True )
# 162 : Sphynx_133.jpg 	(mask: True | bb: True )
# 163 : Sphynx_160.jpg 	(mask: True | bb: True )
# 164 : Sphynx_132.jpg 	(mask: True | bb: True )
# 165 : Sphynx_174.jpg 	(mask: True | bb: True )
# 166 : Sphynx_175.jpg 	(mask: True | bb: True )
# 167 : Sphynx_104.jpg 	(mask: True | bb: True )
# 168 : Sphynx_125.jpg 	(mask: True | bb: True )
# 169 : Sphynx_194.jpg 	(mask: True | bb: True )
# 170 : Sphynx_14.jpg 	(mask: True | bb: True )
# 171 : Sphynx_184.jpg 	(mask: True | bb: True )
# 172 : Sphynx_182.jpg 	(mask: True | bb: True )
# 173 : Sphynx_102.jpg 	(mask: True | bb: True )
# 174 : Sphynx_146.jpg 	(mask: True | bb: True )
# 175 : Sphynx_11.jpg 	(mask: True | bb: True )
# 176 : Sphynx_199.jpg 	(mask: True | bb: True )
# 177 : Sphynx_205.jpg 	(mask: True | bb: True )
# 178 : Sphynx_157.jpg 	(mask: True | bb: True )
# 179 : Sphynx_19.jpg 	(mask: True | bb: True )
# 180 : Sphynx_103.jpg 	(mask: True | bb: True )
# 181 : Sphynx_129.jpg 	(mask: True | bb: True )
# 182 : Sphynx_105.jpg 	(mask: True | bb: True )
# 183 : Sphynx_169.jpg 	(mask: True | bb: True )
# 184 : Sphynx_134.jpg 	(mask: True | bb: True )
# 185 : Sphynx_168.jpg 	(mask: True | bb: True )
# 186 : Sphynx_181.jpg 	(mask: True | bb: True )
# 187 : Sphynx_15.jpg 	(mask: True | bb: True )
# 188 : Sphynx_136.jpg 	(mask: True | bb: True )
# 189 : Sphynx_200.jpg 	(mask: True | bb: True )
# 190 : Sphynx_158.jpg 	(mask: True | bb: True )
# 191 : Sphynx_137.jpg 	(mask: True | bb: True )
# 192 : Sphynx_206.jpg 	(mask: True | bb: True )
# 193 : Sphynx_145.jpg 	(mask: True | bb: True )
# 194 : Sphynx_159.jpg 	(mask: True | bb: True )
# 195 : Sphynx_190.jpg 	(mask: True | bb: True )
# 196 : Sphynx_130.jpg 	(mask: True | bb: True )
# 197 : Sphynx_119.jpg 	(mask: True | bb: True )
# 198 : Sphynx_167.jpg 	(mask: True | bb: True )
# Reading files for label 'Egyptian_Mau'
# 199 : Egyptian_Mau_108.jpg 	(mask: True | bb: True )
# 200 : Egyptian_Mau_171.jpg 	(mask: True | bb: True )
# 201 : Egyptian_Mau_11.jpg 	(mask: True | bb: True )
# 202 : Egyptian_Mau_136.jpg 	(mask: True | bb: True )
# 203 : Egyptian_Mau_100.jpg 	(mask: True | bb: True )
# 204 : Egyptian_Mau_149.jpg 	(mask: True | bb: True )
# 205 : Egyptian_Mau_130.jpg 	(mask: True | bb: True )
# 206 : Egyptian_Mau_107.jpg 	(mask: True | bb: True )
# 207 : Egyptian_Mau_138.jpg 	(mask: True | bb: True )
# 208 : Egyptian_Mau_168.jpg 	(mask: True | bb: True )
# 209 : Egyptian_Mau_18.jpg 	(mask: True | bb: True )
# 210 : Egyptian_Mau_15.jpg 	(mask: True | bb: True )
# 211 : Egyptian_Mau_147.jpg 	(mask: True | bb: True )
# 212 : Egyptian_Mau_120.jpg 	(mask: True | bb: True )
# 213 : Egyptian_Mau_131.jpg 	(mask: True | bb: True )
# 214 : Egyptian_Mau_16.jpg 	(mask: True | bb: True )
# 215 : Egyptian_Mau_173.jpg 	(mask: True | bb: True )
# 216 : Egyptian_Mau_178.jpg 	(mask: True | bb: True )
# 217 : Egyptian_Mau_128.jpg 	(mask: True | bb: True )
# 218 : Egyptian_Mau_113.jpg 	(mask: True | bb: True )
# 219 : Egyptian_Mau_143.jpg 	(mask: True | bb: True )
# 220 : Egyptian_Mau_161.jpg 	(mask: True | bb: True )
# 221 : Egyptian_Mau_101.jpg 	(mask: True | bb: True )
# 222 : Egyptian_Mau_104.jpg 	(mask: True | bb: True )
# 223 : Egyptian_Mau_12.jpg 	(mask: True | bb: True )
# 224 : Egyptian_Mau_133.jpg 	(mask: True | bb: True )
# 225 : Egyptian_Mau_134.jpg 	(mask: True | bb: True )
# 226 : Egyptian_Mau_122.jpg 	(mask: True | bb: True )
# 227 : Egyptian_Mau_153.jpg 	(mask: True | bb: True )
# 228 : Egyptian_Mau_111.jpg 	(mask: True | bb: True )
# 229 : Egyptian_Mau_109.jpg 	(mask: True | bb: True )
# 230 : Egyptian_Mau_126.jpg 	(mask: True | bb: True )
# 231 : Egyptian_Mau_190.jpg 	(mask: True | bb: True )
# 232 : Egyptian_Mau_154.jpg 	(mask: True | bb: True )
# 233 : Egyptian_Mau_114.jpg 	(mask: True | bb: True )
# 234 : Egyptian_Mau_180.jpg 	(mask: True | bb: True )
# 235 : Egyptian_Mau_165.jpg 	(mask: True | bb: True )
# 236 : Egyptian_Mau_182.jpg 	(mask: True | bb: True )
# 237 : Egyptian_Mau_144.jpg 	(mask: True | bb: True )
# 238 : Egyptian_Mau_146.jpg 	(mask: True | bb: True )
# 239 : Egyptian_Mau_188.jpg 	(mask: True | bb: True )
# 240 : Egyptian_Mau_151.jpg 	(mask: True | bb: True )
# 241 : Egyptian_Mau_197.jpg 	(mask: True | bb: True )
# 242 : Egyptian_Mau_103.jpg 	(mask: True | bb: True )
# 243 : Egyptian_Mau_116.jpg 	(mask: True | bb: True )
# 244 : Egyptian_Mau_192.jpg 	(mask: True | bb: True )
# 245 : Egyptian_Mau_115.jpg 	(mask: True | bb: True )
# 246 : Egyptian_Mau_119.jpg 	(mask: True | bb: True )
# 247 : Egyptian_Mau_110.jpg 	(mask: True | bb: True )
# 248 : Egyptian_Mau_163.jpg 	(mask: True | bb: True )
# 249 : Egyptian_Mau_164.jpg 	(mask: True | bb: True )
# 250 : Egyptian_Mau_196.jpg 	(mask: True | bb: True )
# 251 : Egyptian_Mau_172.jpg 	(mask: True | bb: True )
# 252 : Egyptian_Mau_185.jpg 	(mask: True | bb: True )
# 253 : Egyptian_Mau_157.jpg 	(mask: True | bb: True )
# 254 : Egyptian_Mau_174.jpg 	(mask: True | bb: True )
# 255 : Egyptian_Mau_187.jpg 	(mask: True | bb: True )
# 256 : Egyptian_Mau_148.jpg 	(mask: True | bb: True )
# 257 : Egyptian_Mau_118.jpg 	(mask: True | bb: True )
# 258 : Egyptian_Mau_10.jpg 	(mask: True | bb: True )
# 259 : Egyptian_Mau_179.jpg 	(mask: True | bb: True )
# 260 : Egyptian_Mau_176.jpg 	(mask: True | bb: True )
# 261 : Egyptian_Mau_112.jpg 	(mask: True | bb: True )
# 262 : Egyptian_Mau_195.jpg 	(mask: True | bb: True )
# 263 : Egyptian_Mau_124.jpg 	(mask: True | bb: True )
# 264 : Egyptian_Mau_181.jpg 	(mask: True | bb: True )
# 265 : Egyptian_Mau_183.jpg 	(mask: True | bb: True )
# 266 : Egyptian_Mau_142.jpg 	(mask: True | bb: True )
# 267 : Egyptian_Mau_141.jpg 	(mask: True | bb: True )
# 268 : Egyptian_Mau_102.jpg 	(mask: True | bb: True )
# 269 : Egyptian_Mau_125.jpg 	(mask: True | bb: True )
# 270 : Egyptian_Mau_127.jpg 	(mask: True | bb: True )
# 271 : Egyptian_Mau_129.jpg 	(mask: True | bb: True )
# 272 : Egyptian_Mau_13.jpg 	(mask: True | bb: True )
# 273 : Egyptian_Mau_184.jpg 	(mask: True | bb: True )
# 274 : Egyptian_Mau_140.jpg 	(mask: True | bb: True )
# 275 : Egyptian_Mau_170.jpg 	(mask: True | bb: True )
# 276 : Egyptian_Mau_160.jpg 	(mask: True | bb: True )
# 277 : Egyptian_Mau_175.jpg 	(mask: True | bb: True )
# 278 : Egyptian_Mau_152.jpg 	(mask: True | bb: True )
# 279 : Egyptian_Mau_121.jpg 	(mask: True | bb: True )
# 280 : Egyptian_Mau_189.jpg 	(mask: True | bb: True )
# 281 : Egyptian_Mau_123.jpg 	(mask: True | bb: True )
# 282 : Egyptian_Mau_194.jpg 	(mask: True | bb: True )
# 283 : Egyptian_Mau_132.jpg 	(mask: True | bb: True )
# 284 : Egyptian_Mau_193.jpg 	(mask: True | bb: True )
# 285 : Egyptian_Mau_106.jpg 	(mask: True | bb: True )
# 286 : Egyptian_Mau_150.jpg 	(mask: True | bb: True )
# 287 : Egyptian_Mau_162.jpg 	(mask: True | bb: True )
# 288 : Egyptian_Mau_117.jpg 	(mask: True | bb: True )
# 289 : Egyptian_Mau_105.jpg 	(mask: True | bb: True )
# 290 : Egyptian_Mau_155.jpg 	(mask: True | bb: True )
# Reading files for label 'Persian'
# 291 : Persian_129.jpg 	(mask: True | bb: True )
# 292 : Persian_217.jpg 	(mask: True | bb: True )
# 293 : Persian_20.jpg 	(mask: True | bb: True )
# 294 : Persian_136.jpg 	(mask: True | bb: True )
# 295 : Persian_173.jpg 	(mask: True | bb: True )
# 296 : Persian_194.jpg 	(mask: True | bb: True )
# 297 : Persian_175.jpg 	(mask: True | bb: True )
# 298 : Persian_15.jpg 	(mask: True | bb: True )
# 299 : Persian_108.jpg 	(mask: True | bb: True )
# 300 : Persian_132.jpg 	(mask: True | bb: True )
# 301 : Persian_107.jpg 	(mask: True | bb: True )
# 302 : Persian_186.jpg 	(mask: True | bb: True )
# 303 : Persian_158.jpg 	(mask: True | bb: True )
# 304 : Persian_185.jpg 	(mask: True | bb: True )
# 305 : Persian_197.jpg 	(mask: True | bb: True )
# 306 : Persian_188.jpg 	(mask: True | bb: True )
# 307 : Persian_121.jpg 	(mask: True | bb: True )
# 308 : Persian_187.jpg 	(mask: True | bb: True )
# 309 : Persian_170.jpg 	(mask: True | bb: True )
# 310 : Persian_152.jpg 	(mask: True | bb: True )
# 311 : Persian_138.jpg 	(mask: True | bb: True )
# 312 : Persian_105.jpg 	(mask: True | bb: True )
# 313 : Persian_122.jpg 	(mask: True | bb: True )
# 314 : Persian_133.jpg 	(mask: True | bb: True )
# 315 : Persian_123.jpg 	(mask: True | bb: True )
# 316 : Persian_104.jpg 	(mask: True | bb: True )
# 317 : Persian_144.jpg 	(mask: True | bb: True )
# 318 : Persian_150.jpg 	(mask: True | bb: True )
# 319 : Persian_128.jpg 	(mask: True | bb: True )
# 320 : Persian_153.jpg 	(mask: True | bb: True )
# 321 : Persian_149.jpg 	(mask: True | bb: True )
# 322 : Persian_112.jpg 	(mask: True | bb: True )
# 323 : Persian_181.jpg 	(mask: True | bb: True )
# 324 : Persian_125.jpg 	(mask: True | bb: True )
# 325 : Persian_201.jpg 	(mask: True | bb: True )
# 326 : Persian_118.jpg 	(mask: True | bb: True )
# 327 : Persian_18.jpg 	(mask: True | bb: True )
# 328 : Persian_169.jpg 	(mask: True | bb: True )
# 329 : Persian_13.jpg 	(mask: True | bb: True )
# 330 : Persian_156.jpg 	(mask: True | bb: True )
# 331 : Persian_162.jpg 	(mask: True | bb: True )
# 332 : Persian_160.jpg 	(mask: True | bb: True )
# 333 : Persian_134.jpg 	(mask: True | bb: True )
# 334 : Persian_101.jpg 	(mask: True | bb: True )
# 335 : Persian_143.jpg 	(mask: True | bb: True )
# 336 : Persian_172.jpg 	(mask: True | bb: True )
# 337 : Persian_19.jpg 	(mask: True | bb: True )
# 338 : Persian_120.jpg 	(mask: True | bb: True )
# 339 : Persian_166.jpg 	(mask: True | bb: True )
# 340 : Persian_135.jpg 	(mask: True | bb: True )
# 341 : Persian_16.jpg 	(mask: True | bb: True )
# 342 : Persian_183.jpg 	(mask: True | bb: True )
# 343 : Persian_100.jpg 	(mask: True | bb: True )
# 344 : Persian_189.jpg 	(mask: True | bb: True )
# 345 : Persian_137.jpg 	(mask: True | bb: True )
# 346 : Persian_206.jpg 	(mask: True | bb: True )
# 347 : Persian_180.jpg 	(mask: True | bb: True )
# 348 : Persian_190.jpg 	(mask: True | bb: True )
# 349 : Persian_159.jpg 	(mask: True | bb: True )
# 350 : Persian_191.jpg 	(mask: True | bb: True )
# 351 : Persian_193.jpg 	(mask: True | bb: True )
# 352 : Persian_102.jpg 	(mask: True | bb: True )
# 353 : Persian_202.jpg 	(mask: True | bb: True )
# 354 : Persian_184.jpg 	(mask: True | bb: True )
# 355 : Persian_111.jpg 	(mask: True | bb: True )
# 356 : Persian_147.jpg 	(mask: True | bb: True )
# 357 : Persian_195.jpg 	(mask: True | bb: True )
# 358 : Persian_161.jpg 	(mask: True | bb: True )
# 359 : Persian_116.jpg 	(mask: True | bb: True )
# 360 : Persian_165.jpg 	(mask: True | bb: True )
# 361 : Persian_182.jpg 	(mask: True | bb: True )
# 362 : Persian_196.jpg 	(mask: True | bb: True )
# 363 : Persian_155.jpg 	(mask: True | bb: True )
# 364 : Persian_200.jpg 	(mask: True | bb: True )
# 365 : Persian_176.jpg 	(mask: True | bb: True )
# 366 : Persian_168.jpg 	(mask: True | bb: True )
# 367 : Persian_106.jpg 	(mask: True | bb: True )
# 368 : Persian_171.jpg 	(mask: True | bb: True )
# 369 : Persian_12.jpg 	(mask: True | bb: True )
# 370 : Persian_139.jpg 	(mask: True | bb: True )
# 371 : Persian_213.jpg 	(mask: True | bb: True )
# 372 : Persian_103.jpg 	(mask: True | bb: True )
# 373 : Persian_145.jpg 	(mask: True | bb: True )
# 374 : Persian_114.jpg 	(mask: True | bb: True )
# 375 : Persian_140.jpg 	(mask: True | bb: True )
# 376 : Persian_174.jpg 	(mask: True | bb: True )
# 377 : Persian_126.jpg 	(mask: True | bb: True )
# 378 : Persian_164.jpg 	(mask: True | bb: True )
# 379 : Persian_17.jpg 	(mask: True | bb: True )
# 380 : Persian_115.jpg 	(mask: True | bb: True )
# 381 : Persian_131.jpg 	(mask: True | bb: True )
# 382 : Persian_10.jpg 	(mask: True | bb: True )
# 383 : Persian_179.jpg 	(mask: True | bb: True )
# 384 : Persian_141.jpg 	(mask: True | bb: True )
# 385 : Persian_192.jpg 	(mask: True | bb: True )
# 386 : Persian_1.jpg 	(mask: True | bb: True )
# 387 : Persian_163.jpg 	(mask: True | bb: True )
# 388 : Persian_14.jpg 	(mask: True | bb: True )
# 389 : Persian_117.jpg 	(mask: True | bb: True )
# 390 : Persian_11.jpg 	(mask: True | bb: True )
# Reading files for label 'Siamese'
# 391 : Siamese_164.jpg 	(mask: True | bb: True )
# 392 : Siamese_133.jpg 	(mask: True | bb: True )
# 393 : Siamese_143.jpg 	(mask: True | bb: True )
# 394 : Siamese_19.jpg 	(mask: True | bb: True )
# 395 : Siamese_112.jpg 	(mask: True | bb: True )
# 396 : Siamese_202.jpg 	(mask: True | bb: True )
# 397 : Siamese_182.jpg 	(mask: True | bb: True )
# 398 : Siamese_127.jpg 	(mask: True | bb: True )
# 399 : Siamese_129.jpg 	(mask: True | bb: True )
# 400 : Siamese_145.jpg 	(mask: True | bb: True )
# 401 : Siamese_184.jpg 	(mask: True | bb: True )
# 402 : Siamese_158.jpg 	(mask: True | bb: True )
# 403 : Siamese_169.jpg 	(mask: True | bb: True )
# 404 : Siamese_116.jpg 	(mask: True | bb: True )
# 405 : Siamese_172.jpg 	(mask: True | bb: True )
# 406 : Siamese_150.jpg 	(mask: True | bb: True )
# 407 : Siamese_175.jpg 	(mask: True | bb: True )
# 408 : Siamese_189.jpg 	(mask: True | bb: True )
# 409 : Siamese_136.jpg 	(mask: True | bb: True )
# 410 : Siamese_161.jpg 	(mask: True | bb: True )
# 411 : Siamese_199.jpg 	(mask: True | bb: True )
# 412 : Siamese_104.jpg 	(mask: True | bb: True )
# 413 : Siamese_14.jpg 	(mask: True | bb: True )
# 414 : Siamese_165.jpg 	(mask: True | bb: True )
# 415 : Siamese_207.jpg 	(mask: True | bb: True )
# 416 : Siamese_146.jpg 	(mask: True | bb: True )
# 417 : Siamese_194.jpg 	(mask: True | bb: True )
# 418 : Siamese_130.jpg 	(mask: True | bb: True )
# 419 : Siamese_139.jpg 	(mask: True | bb: True )
# 420 : Siamese_142.jpg 	(mask: True | bb: True )
# 421 : Siamese_154.jpg 	(mask: True | bb: True )
# 422 : Siamese_100.jpg 	(mask: True | bb: True )
# 423 : Siamese_188.jpg 	(mask: True | bb: True )
# 424 : Siamese_206.jpg 	(mask: True | bb: True )
# 425 : Siamese_205.jpg 	(mask: True | bb: True )
# 426 : Siamese_186.jpg 	(mask: True | bb: True )
# 427 : Siamese_120.jpg 	(mask: True | bb: True )
# 428 : Siamese_152.jpg 	(mask: True | bb: True )
# 429 : Siamese_109.jpg 	(mask: True | bb: True )
# 430 : Siamese_128.jpg 	(mask: True | bb: True )
# 431 : Siamese_140.jpg 	(mask: True | bb: True )
# 432 : Siamese_148.jpg 	(mask: True | bb: True )
# 433 : Siamese_187.jpg 	(mask: True | bb: True )
# 434 : Siamese_181.jpg 	(mask: True | bb: True )
# 435 : Siamese_171.jpg 	(mask: True | bb: True )
# 436 : Siamese_159.jpg 	(mask: True | bb: True )
# 437 : Siamese_119.jpg 	(mask: True | bb: True )
# 438 : Siamese_108.jpg 	(mask: True | bb: True )
# 439 : Siamese_201.jpg 	(mask: True | bb: True )
# 440 : Siamese_17.jpg 	(mask: True | bb: True )
# 441 : Siamese_196.jpg 	(mask: True | bb: True )
# 442 : Siamese_178.jpg 	(mask: True | bb: True )
# 443 : Siamese_170.jpg 	(mask: True | bb: True )
# 444 : Siamese_102.jpg 	(mask: True | bb: True )
# 445 : Siamese_163.jpg 	(mask: True | bb: True )
# 446 : Siamese_18.jpg 	(mask: True | bb: True )
# 447 : Siamese_110.jpg 	(mask: True | bb: True )
# 448 : Siamese_149.jpg 	(mask: True | bb: True )
# 449 : Siamese_131.jpg 	(mask: True | bb: True )
# 450 : Siamese_115.jpg 	(mask: True | bb: True )
# 451 : Siamese_173.jpg 	(mask: True | bb: True )
# 452 : Siamese_122.jpg 	(mask: True | bb: True )
# 453 : Siamese_138.jpg 	(mask: True | bb: True )
# 454 : Siamese_113.jpg 	(mask: True | bb: True )
# 455 : Siamese_101.jpg 	(mask: True | bb: True )
# 456 : Siamese_204.jpg 	(mask: True | bb: True )
# 457 : Siamese_180.jpg 	(mask: True | bb: True )
# 458 : Siamese_183.jpg 	(mask: True | bb: True )
# 459 : Siamese_179.jpg 	(mask: True | bb: True )
# 460 : Siamese_103.jpg 	(mask: True | bb: True )
# 461 : Siamese_141.jpg 	(mask: True | bb: True )
# 462 : Siamese_195.jpg 	(mask: True | bb: True )
# 463 : Siamese_106.jpg 	(mask: True | bb: True )
# 464 : Siamese_126.jpg 	(mask: True | bb: True )
# 465 : Siamese_135.jpg 	(mask: True | bb: True )
# 466 : Siamese_147.jpg 	(mask: True | bb: True )
# 467 : Siamese_155.jpg 	(mask: True | bb: True )
# 468 : Siamese_137.jpg 	(mask: True | bb: True )
# 469 : Siamese_176.jpg 	(mask: True | bb: True )
# 470 : Siamese_156.jpg 	(mask: True | bb: True )
# 471 : Siamese_193.jpg 	(mask: True | bb: True )
# 472 : Siamese_200.jpg 	(mask: True | bb: True )
# 473 : Siamese_208.jpg 	(mask: True | bb: True )
# 474 : Siamese_191.jpg 	(mask: True | bb: True )
# 475 : Siamese_167.jpg 	(mask: True | bb: True )
# 476 : Siamese_114.jpg 	(mask: True | bb: True )
# 477 : Siamese_160.jpg 	(mask: True | bb: True )
# 478 : Siamese_198.jpg 	(mask: True | bb: True )
# 479 : Siamese_185.jpg 	(mask: True | bb: True )
# 480 : Siamese_162.jpg 	(mask: True | bb: True )
# 481 : Siamese_125.jpg 	(mask: True | bb: True )
# 482 : Siamese_168.jpg 	(mask: True | bb: True )
# 483 : Siamese_144.jpg 	(mask: True | bb: True )
# 484 : Siamese_111.jpg 	(mask: True | bb: True )
# 485 : Siamese_203.jpg 	(mask: True | bb: True )
# 486 : Siamese_151.jpg 	(mask: True | bb: True )
# 487 : Siamese_153.jpg 	(mask: True | bb: True )
# 488 : Siamese_117.jpg 	(mask: True | bb: True )
# 489 : Siamese_174.jpg 	(mask: True | bb: True )
# 490 : Siamese_157.jpg 	(mask: True | bb: True )
# Reading files for label 'Birman'
# 491 : Birman_187.jpg 	(mask: True | bb: True )
# 492 : Birman_118.jpg 	(mask: True | bb: True )
# 493 : Birman_128.jpg 	(mask: True | bb: True )
# 494 : Birman_123.jpg 	(mask: True | bb: True )
# 495 : Birman_121.jpg 	(mask: True | bb: True )
# 496 : Birman_127.jpg 	(mask: True | bb: True )
# 497 : Birman_102.jpg 	(mask: True | bb: True )
# 498 : Birman_130.jpg 	(mask: True | bb: True )
# 499 : Birman_163.jpg 	(mask: True | bb: True )
# 500 : Birman_107.jpg 	(mask: True | bb: True )
# 501 : Birman_154.jpg 	(mask: True | bb: True )
# 502 : Birman_122.jpg 	(mask: True | bb: True )
# 503 : Birman_157.jpg 	(mask: True | bb: True )
# 504 : Birman_177.jpg 	(mask: True | bb: True )
# 505 : Birman_131.jpg 	(mask: True | bb: True )
# 506 : Birman_160.jpg 	(mask: True | bb: True )
# 507 : Birman_10.jpg 	(mask: True | bb: True )
# 508 : Birman_143.jpg 	(mask: True | bb: True )
# 509 : Birman_17.jpg 	(mask: True | bb: True )
# 510 : Birman_119.jpg 	(mask: True | bb: True )
# 511 : Birman_171.jpg 	(mask: True | bb: True )
# 512 : Birman_173.jpg 	(mask: True | bb: True )
# 513 : Birman_129.jpg 	(mask: True | bb: True )
# 514 : Birman_168.jpg 	(mask: True | bb: True )
# 515 : Birman_184.jpg 	(mask: True | bb: True )
# 516 : Birman_137.jpg 	(mask: True | bb: True )
# 517 : Birman_180.jpg 	(mask: True | bb: True )
# 518 : Birman_181.jpg 	(mask: True | bb: True )
# 519 : Birman_176.jpg 	(mask: True | bb: True )
# 520 : Birman_175.jpg 	(mask: True | bb: True )
# 521 : Birman_124.jpg 	(mask: True | bb: True )
# 522 : Birman_166.jpg 	(mask: True | bb: True )
# 523 : Birman_144.jpg 	(mask: True | bb: True )
# 524 : Birman_149.jpg 	(mask: True | bb: True )
# 525 : Birman_152.jpg 	(mask: True | bb: True )
# 526 : Birman_169.jpg 	(mask: True | bb: True )
# 527 : Birman_140.jpg 	(mask: True | bb: True )
# 528 : Birman_179.jpg 	(mask: True | bb: True )
# 529 : Birman_100.jpg 	(mask: True | bb: True )
# 530 : Birman_109.jpg 	(mask: True | bb: True )
# 531 : Birman_112.jpg 	(mask: True | bb: True )
# 532 : Birman_138.jpg 	(mask: True | bb: True )
# 533 : Birman_103.jpg 	(mask: True | bb: True )
# 534 : Birman_147.jpg 	(mask: True | bb: True )
# 535 : Birman_156.jpg 	(mask: True | bb: True )
# 536 : Birman_132.jpg 	(mask: True | bb: True )
# 537 : Birman_11.jpg 	(mask: True | bb: True )
# 538 : Birman_185.jpg 	(mask: True | bb: True )
# 539 : Birman_141.jpg 	(mask: True | bb: True )
# 540 : Birman_146.jpg 	(mask: True | bb: True )
# 541 : Birman_161.jpg 	(mask: True | bb: True )
# 542 : Birman_170.jpg 	(mask: True | bb: True )
# 543 : Birman_155.jpg 	(mask: True | bb: True )
# 544 : Birman_158.jpg 	(mask: True | bb: True )
# 545 : Birman_105.jpg 	(mask: True | bb: True )
# 546 : Birman_14.jpg 	(mask: True | bb: True )
# 547 : Birman_106.jpg 	(mask: True | bb: True )
# 548 : Birman_135.jpg 	(mask: True | bb: True )
# 549 : Birman_178.jpg 	(mask: True | bb: True )
# 550 : Birman_165.jpg 	(mask: True | bb: True )
# 551 : Birman_18.jpg 	(mask: True | bb: True )
# 552 : Birman_15.jpg 	(mask: True | bb: True )
# 553 : Birman_189.jpg 	(mask: True | bb: True )
# 554 : Birman_174.jpg 	(mask: True | bb: True )
# 555 : Birman_162.jpg 	(mask: True | bb: True )
# 556 : Birman_183.jpg 	(mask: True | bb: True )
# 557 : Birman_12.jpg 	(mask: True | bb: True )
# 558 : Birman_159.jpg 	(mask: True | bb: True )
# 559 : Birman_186.jpg 	(mask: True | bb: True )
# 560 : Birman_172.jpg 	(mask: True | bb: True )
# 561 : Birman_164.jpg 	(mask: True | bb: True )
# 562 : Birman_126.jpg 	(mask: True | bb: True )
# 563 : Birman_188.jpg 	(mask: True | bb: True )
# 564 : Birman_16.jpg 	(mask: True | bb: True )
# 565 : Birman_113.jpg 	(mask: True | bb: True )
# 566 : Birman_153.jpg 	(mask: True | bb: True )
# 567 : Birman_13.jpg 	(mask: True | bb: True )
# 568 : Birman_136.jpg 	(mask: True | bb: True )
# 569 : Birman_190.jpg 	(mask: True | bb: True )
# 570 : Birman_110.jpg 	(mask: True | bb: True )
# 571 : Birman_151.jpg 	(mask: True | bb: True )
# 572 : Birman_134.jpg 	(mask: True | bb: True )
# 573 : Birman_145.jpg 	(mask: True | bb: True )
# 574 : Birman_116.jpg 	(mask: True | bb: True )
# 575 : Birman_142.jpg 	(mask: True | bb: True )
# 576 : Birman_139.jpg 	(mask: True | bb: True )
# 577 : Birman_148.jpg 	(mask: True | bb: True )
# 578 : Birman_133.jpg 	(mask: True | bb: True )
# 579 : Birman_125.jpg 	(mask: True | bb: True )
# 580 : Birman_108.jpg 	(mask: True | bb: True )
# 581 : Birman_111.jpg 	(mask: True | bb: True )
# 582 : Birman_104.jpg 	(mask: True | bb: True )
# 583 : Birman_115.jpg 	(mask: True | bb: True )
# 584 : Birman_150.jpg 	(mask: True | bb: True )
# 585 : Birman_182.jpg 	(mask: True | bb: True )
# 586 : Birman_167.jpg 	(mask: True | bb: True )
# 587 : Birman_120.jpg 	(mask: True | bb: True )
# 588 : Birman_101.jpg 	(mask: True | bb: True )
# 589 : Birman_117.jpg 	(mask: True | bb: True )
# 590 : Birman_114.jpg 	(mask: True | bb: True )
# Reading files for label 'Bombay'
# 591 : Bombay_11.jpg 	(mask: True | bb: True )
# 592 : Bombay_13.jpg 	(mask: True | bb: True )
# 593 : Bombay_132.jpg 	(mask: True | bb: True )
# 594 : Bombay_126.jpg 	(mask: True | bb: True )
# 595 : Bombay_193.jpg 	(mask: True | bb: True )
# 596 : Bombay_144.jpg 	(mask: True | bb: True )
# 597 : Bombay_158.jpg 	(mask: True | bb: True )
# 598 : Bombay_127.jpg 	(mask: True | bb: True )
# 599 : Bombay_169.jpg 	(mask: True | bb: True )
# 600 : Bombay_171.jpg 	(mask: True | bb: True )
# 601 : Bombay_145.jpg 	(mask: True | bb: True )
# 602 : Bombay_170.jpg 	(mask: True | bb: True )
# 603 : Bombay_141.jpg 	(mask: True | bb: True )
# 604 : Bombay_185.jpg 	(mask: True | bb: True )
# 605 : Bombay_139.jpg 	(mask: True | bb: True )
# 606 : Bombay_184.jpg 	(mask: True | bb: True )
# 607 : Bombay_1.jpg 	(mask: True | bb: True )
# 608 : Bombay_143.jpg 	(mask: True | bb: True )
# 609 : Bombay_108.jpg 	(mask: True | bb: True )
# 610 : Bombay_191.jpg 	(mask: True | bb: True )
# 611 : Bombay_179.jpg 	(mask: True | bb: True )
# 612 : Bombay_134.jpg 	(mask: True | bb: True )
# 613 : Bombay_175.jpg 	(mask: True | bb: True )
# 614 : Bombay_180.jpg 	(mask: True | bb: True )
# 615 : Bombay_105.jpg 	(mask: True | bb: True )
# 616 : Bombay_114.jpg 	(mask: True | bb: True )
# 617 : Bombay_10.jpg 	(mask: True | bb: True )
# 618 : Bombay_166.jpg 	(mask: True | bb: True )
# 619 : Bombay_151.jpg 	(mask: True | bb: True )
# 620 : Bombay_173.jpg 	(mask: True | bb: True )
# 621 : Bombay_122.jpg 	(mask: True | bb: True )
# 622 : Bombay_131.jpg 	(mask: True | bb: True )
# 623 : Bombay_186.jpg 	(mask: True | bb: True )
# 624 : Bombay_101.jpg 	(mask: True | bb: True )
# 625 : Bombay_162.jpg 	(mask: True | bb: True )
# 626 : Bombay_136.jpg 	(mask: True | bb: True )
# 627 : Bombay_16.jpg 	(mask: True | bb: True )
# 628 : Bombay_140.jpg 	(mask: True | bb: True )
# 629 : Bombay_150.jpg 	(mask: True | bb: True )
# 630 : Bombay_192.jpg 	(mask: True | bb: True )
# 631 : Bombay_182.jpg 	(mask: True | bb: True )
# 632 : Bombay_177.jpg 	(mask: True | bb: True )
# 633 : Bombay_174.jpg 	(mask: True | bb: True )
# 634 : Bombay_198.jpg 	(mask: True | bb: True )
# 635 : Bombay_172.jpg 	(mask: True | bb: True )
# 636 : Bombay_116.jpg 	(mask: True | bb: True )
# 637 : Bombay_104.jpg 	(mask: True | bb: True )
# 638 : Bombay_109.jpg 	(mask: True | bb: True )
# 639 : Bombay_159.jpg 	(mask: True | bb: True )
# 640 : Bombay_121.jpg 	(mask: True | bb: True )
# 641 : Bombay_189.jpg 	(mask: True | bb: True )
# 642 : Bombay_133.jpg 	(mask: True | bb: True )
# 643 : Bombay_106.jpg 	(mask: True | bb: True )
# 644 : Bombay_168.jpg 	(mask: True | bb: True )
# 645 : Bombay_111.jpg 	(mask: True | bb: True )
# 646 : Bombay_190.jpg 	(mask: True | bb: True )
# 647 : Bombay_138.jpg 	(mask: True | bb: True )
# 648 : Bombay_112.jpg 	(mask: True | bb: True )
# 649 : Bombay_103.jpg 	(mask: True | bb: True )
# 650 : Bombay_161.jpg 	(mask: True | bb: True )
# 651 : Bombay_123.jpg 	(mask: True | bb: True )
# 652 : Bombay_102.jpg 	(mask: True | bb: True )
# 653 : Bombay_137.jpg 	(mask: True | bb: True )
# 654 : Bombay_178.jpg 	(mask: True | bb: True )
# 655 : Bombay_154.jpg 	(mask: True | bb: True )
# 656 : Bombay_118.jpg 	(mask: True | bb: True )
# 657 : Bombay_156.jpg 	(mask: True | bb: True )
# 658 : Bombay_148.jpg 	(mask: True | bb: True )
# 659 : Bombay_160.jpg 	(mask: True | bb: True )
# 660 : Bombay_128.jpg 	(mask: True | bb: True )
# 661 : Bombay_155.jpg 	(mask: True | bb: True )
# 662 : Bombay_18.jpg 	(mask: True | bb: True )
# 663 : Bombay_117.jpg 	(mask: True | bb: True )
# 664 : Bombay_157.jpg 	(mask: True | bb: True )
# 665 : Bombay_130.jpg 	(mask: True | bb: True )
# 666 : Bombay_183.jpg 	(mask: True | bb: True )
# 667 : Bombay_125.jpg 	(mask: True | bb: True )
# 668 : Bombay_12.jpg 	(mask: True | bb: True )
# 669 : Bombay_152.jpg 	(mask: True | bb: True )
# 670 : Bombay_163.jpg 	(mask: True | bb: True )
# 671 : Bombay_146.jpg 	(mask: True | bb: True )
# 672 : Bombay_129.jpg 	(mask: True | bb: True )
# 673 : Bombay_167.jpg 	(mask: True | bb: True )
# 674 : Bombay_176.jpg 	(mask: True | bb: True )
# 675 : Bombay_14.jpg 	(mask: True | bb: True )
# 676 : Bombay_113.jpg 	(mask: True | bb: True )
# 677 : Bombay_188.jpg 	(mask: True | bb: True )
# 678 : Bombay_153.jpg 	(mask: True | bb: True )
# 679 : Bombay_120.jpg 	(mask: True | bb: True )
# 680 : Bombay_135.jpg 	(mask: True | bb: True )
# 681 : Bombay_110.jpg 	(mask: True | bb: True )
# 682 : Bombay_15.jpg 	(mask: True | bb: True )
# 683 : Bombay_194.jpg 	(mask: True | bb: True )
# 684 : Bombay_100.jpg 	(mask: True | bb: True )
# 685 : Bombay_107.jpg 	(mask: True | bb: True )
# 686 : Bombay_119.jpg 	(mask: True | bb: True )
# 687 : Bombay_164.jpg 	(mask: True | bb: True )
# 688 : Bombay_19.jpg 	(mask: True | bb: True )
# 689 : Bombay_181.jpg 	(mask: True | bb: True )
# 690 : Bombay_115.jpg 	(mask: True | bb: True )
# Reading files for label 'Russian_Blue'
# 691 : Russian_Blue_198.jpg 	(mask: True | bb: True )
# 692 : Russian_Blue_197.jpg 	(mask: True | bb: True )
# 693 : Russian_Blue_125.jpg 	(mask: True | bb: True )
# 694 : Russian_Blue_10.jpg 	(mask: True | bb: True )
# 695 : Russian_Blue_194.jpg 	(mask: True | bb: True )
# 696 : Russian_Blue_12.jpg 	(mask: True | bb: True )
# 697 : Russian_Blue_131.jpg 	(mask: True | bb: True )
# 698 : Russian_Blue_186.jpg 	(mask: True | bb: True )
# 699 : Russian_Blue_150.jpg 	(mask: True | bb: True )
# 700 : Russian_Blue_14.jpg 	(mask: True | bb: True )
# 701 : Russian_Blue_169.jpg 	(mask: True | bb: True )
# 702 : Russian_Blue_200.jpg 	(mask: True | bb: True )
# 703 : Russian_Blue_158.jpg 	(mask: True | bb: True )
# 704 : Russian_Blue_16.jpg 	(mask: True | bb: True )
# 705 : Russian_Blue_199.jpg 	(mask: True | bb: True )
# 706 : Russian_Blue_151.jpg 	(mask: True | bb: True )
# 707 : Russian_Blue_165.jpg 	(mask: True | bb: True )
# 708 : Russian_Blue_149.jpg 	(mask: True | bb: True )
# 709 : Russian_Blue_152.jpg 	(mask: True | bb: True )
# 710 : Russian_Blue_179.jpg 	(mask: True | bb: True )
# 711 : Russian_Blue_106.jpg 	(mask: True | bb: True )
# 712 : Russian_Blue_140.jpg 	(mask: True | bb: True )
# 713 : Russian_Blue_155.jpg 	(mask: True | bb: True )
# 714 : Russian_Blue_101.jpg 	(mask: True | bb: True )
# 715 : Russian_Blue_132.jpg 	(mask: True | bb: True )
# 716 : Russian_Blue_177.jpg 	(mask: True | bb: True )
# 717 : Russian_Blue_174.jpg 	(mask: True | bb: True )
# 718 : Russian_Blue_1.jpg 	(mask: True | bb: True )
# 719 : Russian_Blue_114.jpg 	(mask: True | bb: True )
# 720 : Russian_Blue_182.jpg 	(mask: True | bb: True )
# 721 : Russian_Blue_128.jpg 	(mask: True | bb: True )
# 722 : Russian_Blue_117.jpg 	(mask: True | bb: True )
# 723 : Russian_Blue_147.jpg 	(mask: True | bb: True )
# 724 : Russian_Blue_184.jpg 	(mask: True | bb: True )
# 725 : Russian_Blue_119.jpg 	(mask: True | bb: True )
# 726 : Russian_Blue_162.jpg 	(mask: True | bb: True )
# 727 : Russian_Blue_13.jpg 	(mask: True | bb: True )
# 728 : Russian_Blue_108.jpg 	(mask: True | bb: True )
# 729 : Russian_Blue_156.jpg 	(mask: True | bb: True )
# 730 : Russian_Blue_19.jpg 	(mask: True | bb: True )
# 731 : Russian_Blue_187.jpg 	(mask: True | bb: True )
# 732 : Russian_Blue_170.jpg 	(mask: True | bb: True )
# 733 : Russian_Blue_180.jpg 	(mask: True | bb: True )
# 734 : Russian_Blue_181.jpg 	(mask: True | bb: True )
# 735 : Russian_Blue_160.jpg 	(mask: True | bb: True )
# 736 : Russian_Blue_154.jpg 	(mask: True | bb: True )
# 737 : Russian_Blue_183.jpg 	(mask: True | bb: True )
# 738 : Russian_Blue_178.jpg 	(mask: True | bb: True )
# 739 : Russian_Blue_195.jpg 	(mask: True | bb: True )
# 740 : Russian_Blue_146.jpg 	(mask: True | bb: True )
# 741 : Russian_Blue_133.jpg 	(mask: True | bb: True )
# 742 : Russian_Blue_113.jpg 	(mask: True | bb: True )
# 743 : Russian_Blue_100.jpg 	(mask: True | bb: True )
# 744 : Russian_Blue_120.jpg 	(mask: True | bb: True )
# 745 : Russian_Blue_104.jpg 	(mask: True | bb: True )
# 746 : Russian_Blue_192.jpg 	(mask: True | bb: True )
# 747 : Russian_Blue_124.jpg 	(mask: True | bb: True )
# 748 : Russian_Blue_109.jpg 	(mask: True | bb: True )
# 749 : Russian_Blue_130.jpg 	(mask: True | bb: True )
# 750 : Russian_Blue_172.jpg 	(mask: True | bb: True )
# 751 : Russian_Blue_123.jpg 	(mask: True | bb: True )
# 752 : Russian_Blue_145.jpg 	(mask: True | bb: True )
# 753 : Russian_Blue_191.jpg 	(mask: True | bb: True )
# 754 : Russian_Blue_157.jpg 	(mask: True | bb: True )
# 755 : Russian_Blue_153.jpg 	(mask: True | bb: True )
# 756 : Russian_Blue_112.jpg 	(mask: True | bb: True )
# 757 : Russian_Blue_118.jpg 	(mask: True | bb: True )
# 758 : Russian_Blue_185.jpg 	(mask: True | bb: True )
# 759 : Russian_Blue_143.jpg 	(mask: True | bb: True )
# 760 : Russian_Blue_116.jpg 	(mask: True | bb: True )
# 761 : Russian_Blue_193.jpg 	(mask: True | bb: True )
# 762 : Russian_Blue_159.jpg 	(mask: True | bb: True )
# 763 : Russian_Blue_103.jpg 	(mask: True | bb: True )
# 764 : Russian_Blue_122.jpg 	(mask: True | bb: True )
# 765 : Russian_Blue_196.jpg 	(mask: True | bb: True )
# 766 : Russian_Blue_129.jpg 	(mask: True | bb: True )
# 767 : Russian_Blue_171.jpg 	(mask: True | bb: True )
# 768 : Russian_Blue_176.jpg 	(mask: True | bb: True )
# 769 : Russian_Blue_142.jpg 	(mask: True | bb: True )
# 770 : Russian_Blue_102.jpg 	(mask: True | bb: True )
# 771 : Russian_Blue_136.jpg 	(mask: True | bb: True )
# 772 : Russian_Blue_188.jpg 	(mask: True | bb: True )
# 773 : Russian_Blue_135.jpg 	(mask: True | bb: True )
# 774 : Russian_Blue_17.jpg 	(mask: True | bb: True )
# 775 : Russian_Blue_168.jpg 	(mask: True | bb: True )
# 776 : Russian_Blue_111.jpg 	(mask: True | bb: True )
# 777 : Russian_Blue_107.jpg 	(mask: True | bb: True )
# 778 : Russian_Blue_175.jpg 	(mask: True | bb: True )
# 779 : Russian_Blue_164.jpg 	(mask: True | bb: True )
# 780 : Russian_Blue_139.jpg 	(mask: True | bb: True )
# 781 : Russian_Blue_127.jpg 	(mask: True | bb: True )
# 782 : Russian_Blue_18.jpg 	(mask: True | bb: True )
# 783 : Russian_Blue_144.jpg 	(mask: True | bb: True )
# 784 : Russian_Blue_148.jpg 	(mask: True | bb: True )
# 785 : Russian_Blue_161.jpg 	(mask: True | bb: True )
# 786 : Russian_Blue_137.jpg 	(mask: True | bb: True )
# 787 : Russian_Blue_166.jpg 	(mask: True | bb: True )
# 788 : Russian_Blue_173.jpg 	(mask: True | bb: True )
# 789 : Russian_Blue_110.jpg 	(mask: True | bb: True )
# 790 : Russian_Blue_115.jpg 	(mask: True | bb: True )
# Reading files for label 'Bengal'
# 791 : Bengal_12.jpg 	(mask: True | bb: True )
# 792 : Bengal_166.jpg 	(mask: True | bb: True )
# 793 : Bengal_170.jpg 	(mask: True | bb: True )
# 794 : Bengal_125.jpg 	(mask: True | bb: True )
# 795 : Bengal_139.jpg 	(mask: True | bb: True )
# 796 : Bengal_162.jpg 	(mask: True | bb: True )
# 797 : Bengal_11.jpg 	(mask: True | bb: True )
# 798 : Bengal_138.jpg 	(mask: True | bb: True )
# 799 : Bengal_182.jpg 	(mask: True | bb: True )
# 800 : Bengal_150.jpg 	(mask: True | bb: True )
# 801 : Bengal_104.jpg 	(mask: True | bb: True )
# 802 : Bengal_123.jpg 	(mask: True | bb: True )
# 803 : Bengal_126.jpg 	(mask: True | bb: True )
# 804 : Bengal_177.jpg 	(mask: True | bb: True )
# 805 : Bengal_174.jpg 	(mask: True | bb: True )
# 806 : Bengal_130.jpg 	(mask: True | bb: True )
# 807 : Bengal_155.jpg 	(mask: True | bb: True )
# 808 : Bengal_108.jpg 	(mask: True | bb: True )
# 809 : Bengal_143.jpg 	(mask: True | bb: True )
# 810 : Bengal_142.jpg 	(mask: True | bb: True )
# 811 : Bengal_124.jpg 	(mask: True | bb: True )
# 812 : Bengal_180.jpg 	(mask: True | bb: True )
# 813 : Bengal_146.jpg 	(mask: True | bb: True )
# 814 : Bengal_168.jpg 	(mask: True | bb: True )
# 815 : Bengal_100.jpg 	(mask: True | bb: True )
# 816 : Bengal_153.jpg 	(mask: True | bb: True )
# 817 : Bengal_120.jpg 	(mask: True | bb: True )
# 818 : Bengal_165.jpg 	(mask: True | bb: True )
# 819 : Bengal_141.jpg 	(mask: True | bb: True )
# 820 : Bengal_122.jpg 	(mask: True | bb: True )
# 821 : Bengal_176.jpg 	(mask: True | bb: True )
# 822 : Bengal_140.jpg 	(mask: True | bb: True )
# 823 : Bengal_133.jpg 	(mask: True | bb: True )
# 824 : Bengal_184.jpg 	(mask: True | bb: True )
# 825 : Bengal_137.jpg 	(mask: True | bb: True )
# 826 : Bengal_187.jpg 	(mask: True | bb: True )
# 827 : Bengal_144.jpg 	(mask: True | bb: True )
# 828 : Bengal_157.jpg 	(mask: True | bb: True )
# 829 : Bengal_161.jpg 	(mask: True | bb: True )
# 830 : Bengal_107.jpg 	(mask: True | bb: True )
# 831 : Bengal_169.jpg 	(mask: True | bb: True )
# 832 : Bengal_114.jpg 	(mask: True | bb: True )
# 833 : Bengal_18.jpg 	(mask: True | bb: True )
# 834 : Bengal_101.jpg 	(mask: True | bb: True )
# 835 : Bengal_191.jpg 	(mask: True | bb: True )
# 836 : Bengal_156.jpg 	(mask: True | bb: True )
# 837 : Bengal_185.jpg 	(mask: True | bb: True )
# 838 : Bengal_17.jpg 	(mask: True | bb: True )
# 839 : Bengal_148.jpg 	(mask: True | bb: True )
# 840 : Bengal_121.jpg 	(mask: True | bb: True )
# 841 : Bengal_109.jpg 	(mask: True | bb: True )
# 842 : Bengal_113.jpg 	(mask: True | bb: True )
# 843 : Bengal_151.jpg 	(mask: True | bb: True )
# 844 : Bengal_183.jpg 	(mask: True | bb: True )
# 845 : Bengal_136.jpg 	(mask: True | bb: True )
# 846 : Bengal_128.jpg 	(mask: True | bb: True )
# 847 : Bengal_171.jpg 	(mask: True | bb: True )
# 848 : Bengal_117.jpg 	(mask: True | bb: True )
# 849 : Bengal_134.jpg 	(mask: True | bb: True )
# 850 : Bengal_16.jpg 	(mask: True | bb: True )
# 851 : Bengal_167.jpg 	(mask: True | bb: True )
# 852 : Bengal_129.jpg 	(mask: True | bb: True )
# 853 : Bengal_112.jpg 	(mask: True | bb: True )
# 854 : Bengal_173.jpg 	(mask: True | bb: True )
# 855 : Bengal_14.jpg 	(mask: True | bb: True )
# 856 : Bengal_127.jpg 	(mask: True | bb: True )
# 857 : Bengal_154.jpg 	(mask: True | bb: True )
# 858 : Bengal_152.jpg 	(mask: True | bb: True )
# 859 : Bengal_119.jpg 	(mask: True | bb: True )
# 860 : Bengal_159.jpg 	(mask: True | bb: True )
# 861 : Bengal_110.jpg 	(mask: True | bb: True )
# 862 : Bengal_118.jpg 	(mask: True | bb: True )
# 863 : Bengal_186.jpg 	(mask: True | bb: True )
# 864 : Bengal_10.jpg 	(mask: True | bb: True )
# 865 : Bengal_145.jpg 	(mask: True | bb: True )
# 866 : Bengal_131.jpg 	(mask: True | bb: True )
# 867 : Bengal_188.jpg 	(mask: True | bb: True )
# 868 : Bengal_147.jpg 	(mask: True | bb: True )
# 869 : Bengal_164.jpg 	(mask: True | bb: True )
# 870 : Bengal_102.jpg 	(mask: True | bb: True )
# 871 : Bengal_158.jpg 	(mask: True | bb: True )
# 872 : Bengal_132.jpg 	(mask: True | bb: True )
# 873 : Bengal_13.jpg 	(mask: True | bb: True )
# 874 : Bengal_135.jpg 	(mask: True | bb: True )
# 875 : Bengal_172.jpg 	(mask: True | bb: True )
# 876 : Bengal_116.jpg 	(mask: True | bb: True )
# 877 : Bengal_106.jpg 	(mask: True | bb: True )
# 878 : Bengal_189.jpg 	(mask: True | bb: True )
# 879 : Bengal_178.jpg 	(mask: True | bb: True )
# 880 : Bengal_190.jpg 	(mask: True | bb: True )
# 881 : Bengal_105.jpg 	(mask: True | bb: True )
# 882 : Bengal_160.jpg 	(mask: True | bb: True )
# 883 : Bengal_115.jpg 	(mask: True | bb: True )
# 884 : Bengal_103.jpg 	(mask: True | bb: True )
# 885 : Bengal_149.jpg 	(mask: True | bb: True )
# 886 : Bengal_179.jpg 	(mask: True | bb: True )
# 887 : Bengal_163.jpg 	(mask: True | bb: True )
# 888 : Bengal_15.jpg 	(mask: True | bb: True )
# Reading files for label 'Maine_Coon'
# 889 : Maine_Coon_100.jpg 	(mask: True | bb: True )
# 890 : Maine_Coon_143.jpg 	(mask: True | bb: True )
# 891 : Maine_Coon_111.jpg 	(mask: True | bb: True )
# 892 : Maine_Coon_213.jpg 	(mask: True | bb: True )
# 893 : Maine_Coon_121.jpg 	(mask: True | bb: True )
# 894 : Maine_Coon_115.jpg 	(mask: True | bb: True )
# 895 : Maine_Coon_138.jpg 	(mask: True | bb: True )
# 896 : Maine_Coon_139.jpg 	(mask: True | bb: True )
# 897 : Maine_Coon_132.jpg 	(mask: True | bb: True )
# 898 : Maine_Coon_112.jpg 	(mask: True | bb: True )
# 899 : Maine_Coon_184.jpg 	(mask: True | bb: True )
# 900 : Maine_Coon_193.jpg 	(mask: True | bb: True )
# 901 : Maine_Coon_142.jpg 	(mask: True | bb: True )
# 902 : Maine_Coon_117.jpg 	(mask: True | bb: True )
# 903 : Maine_Coon_105.jpg 	(mask: True | bb: True )
# 904 : Maine_Coon_164.jpg 	(mask: True | bb: True )
# 905 : Maine_Coon_108.jpg 	(mask: True | bb: True )
# 906 : Maine_Coon_13.jpg 	(mask: True | bb: True )
# 907 : Maine_Coon_197.jpg 	(mask: True | bb: True )
# 908 : Maine_Coon_124.jpg 	(mask: True | bb: True )
# 909 : Maine_Coon_141.jpg 	(mask: True | bb: True )
# 910 : Maine_Coon_205.jpg 	(mask: True | bb: True )
# 911 : Maine_Coon_17.jpg 	(mask: True | bb: True )
# 912 : Maine_Coon_180.jpg 	(mask: True | bb: True )
# 913 : Maine_Coon_189.jpg 	(mask: True | bb: True )
# 914 : Maine_Coon_169.jpg 	(mask: True | bb: True )
# 915 : Maine_Coon_186.jpg 	(mask: True | bb: True )
# 916 : Maine_Coon_204.jpg 	(mask: True | bb: True )
# 917 : Maine_Coon_144.jpg 	(mask: True | bb: True )
# 918 : Maine_Coon_10.jpg 	(mask: True | bb: True )
# 919 : Maine_Coon_168.jpg 	(mask: True | bb: True )
# 920 : Maine_Coon_149.jpg 	(mask: True | bb: True )
# 921 : Maine_Coon_187.jpg 	(mask: True | bb: True )
# 922 : Maine_Coon_171.jpg 	(mask: True | bb: True )
# 923 : Maine_Coon_101.jpg 	(mask: True | bb: True )
# 924 : Maine_Coon_1.jpg 	(mask: True | bb: True )
# 925 : Maine_Coon_160.jpg 	(mask: True | bb: True )
# 926 : Maine_Coon_195.jpg 	(mask: True | bb: True )
# 927 : Maine_Coon_127.jpg 	(mask: True | bb: True )
# 928 : Maine_Coon_176.jpg 	(mask: True | bb: True )
# 929 : Maine_Coon_201.jpg 	(mask: True | bb: True )
# 930 : Maine_Coon_152.jpg 	(mask: True | bb: True )
# 931 : Maine_Coon_116.jpg 	(mask: True | bb: True )
# 932 : Maine_Coon_131.jpg 	(mask: True | bb: True )
# 933 : Maine_Coon_106.jpg 	(mask: True | bb: True )
# 934 : Maine_Coon_175.jpg 	(mask: True | bb: True )
# 935 : Maine_Coon_155.jpg 	(mask: True | bb: True )
# 936 : Maine_Coon_102.jpg 	(mask: True | bb: True )
# 937 : Maine_Coon_140.jpg 	(mask: True | bb: True )
# 938 : Maine_Coon_151.jpg 	(mask: True | bb: True )
# 939 : Maine_Coon_211.jpg 	(mask: True | bb: True )
# 940 : Maine_Coon_162.jpg 	(mask: True | bb: True )
# 941 : Maine_Coon_136.jpg 	(mask: True | bb: True )
# 942 : Maine_Coon_194.jpg 	(mask: True | bb: True )
# 943 : Maine_Coon_150.jpg 	(mask: True | bb: True )
# 944 : Maine_Coon_163.jpg 	(mask: True | bb: True )
# 945 : Maine_Coon_109.jpg 	(mask: True | bb: True )
# 946 : Maine_Coon_182.jpg 	(mask: True | bb: True )
# 947 : Maine_Coon_174.jpg 	(mask: True | bb: True )
# 948 : Maine_Coon_210.jpg 	(mask: True | bb: True )
# 949 : Maine_Coon_214.jpg 	(mask: True | bb: True )
# 950 : Maine_Coon_147.jpg 	(mask: True | bb: True )
# 951 : Maine_Coon_107.jpg 	(mask: True | bb: True )
# 952 : Maine_Coon_18.jpg 	(mask: True | bb: True )
# 953 : Maine_Coon_219.jpg 	(mask: True | bb: True )
# 954 : Maine_Coon_148.jpg 	(mask: True | bb: True )
# 955 : Maine_Coon_134.jpg 	(mask: True | bb: True )
# 956 : Maine_Coon_128.jpg 	(mask: True | bb: True )
# 957 : Maine_Coon_207.jpg 	(mask: True | bb: True )
# 958 : Maine_Coon_203.jpg 	(mask: True | bb: True )
# 959 : Maine_Coon_154.jpg 	(mask: True | bb: True )
# 960 : Maine_Coon_206.jpg 	(mask: True | bb: True )
# 961 : Maine_Coon_133.jpg 	(mask: True | bb: True )
# 962 : Maine_Coon_157.jpg 	(mask: True | bb: True )
# 963 : Maine_Coon_170.jpg 	(mask: True | bb: True )
# 964 : Maine_Coon_192.jpg 	(mask: True | bb: True )
# 965 : Maine_Coon_161.jpg 	(mask: True | bb: True )
# 966 : Maine_Coon_158.jpg 	(mask: True | bb: True )
# 967 : Maine_Coon_19.jpg 	(mask: True | bb: True )
# 968 : Maine_Coon_137.jpg 	(mask: True | bb: True )
# 969 : Maine_Coon_173.jpg 	(mask: True | bb: True )
# 970 : Maine_Coon_217.jpg 	(mask: True | bb: True )
# 971 : Maine_Coon_167.jpg 	(mask: True | bb: True )
# 972 : Maine_Coon_135.jpg 	(mask: True | bb: True )
# 973 : Maine_Coon_208.jpg 	(mask: True | bb: True )
# 974 : Maine_Coon_191.jpg 	(mask: True | bb: True )
# 975 : Maine_Coon_103.jpg 	(mask: True | bb: True )
# 976 : Maine_Coon_16.jpg 	(mask: True | bb: True )
# 977 : Maine_Coon_196.jpg 	(mask: True | bb: True )
# 978 : Maine_Coon_146.jpg 	(mask: True | bb: True )
# 979 : Maine_Coon_119.jpg 	(mask: True | bb: True )
# 980 : Maine_Coon_123.jpg 	(mask: True | bb: True )
# 981 : Maine_Coon_14.jpg 	(mask: True | bb: True )
# 982 : Maine_Coon_110.jpg 	(mask: True | bb: True )
# 983 : Maine_Coon_104.jpg 	(mask: True | bb: True )
# 984 : Maine_Coon_129.jpg 	(mask: True | bb: True )
# 985 : Maine_Coon_145.jpg 	(mask: True | bb: True )
# 986 : Maine_Coon_126.jpg 	(mask: True | bb: True )
# 987 : Maine_Coon_159.jpg 	(mask: True | bb: True )
# 988 : Maine_Coon_153.jpg 	(mask: True | bb: True )
# Reading files for label 'Ragdoll'
# 989 : Ragdoll_159.jpg 	(mask: True | bb: True )
# 990 : Ragdoll_201.jpg 	(mask: True | bb: True )
# 991 : Ragdoll_141.jpg 	(mask: True | bb: True )
# 992 : Ragdoll_121.jpg 	(mask: True | bb: True )
# 993 : Ragdoll_114.jpg 	(mask: True | bb: True )
# 994 : Ragdoll_132.jpg 	(mask: True | bb: True )
# 995 : Ragdoll_169.jpg 	(mask: True | bb: True )
# 996 : Ragdoll_106.jpg 	(mask: True | bb: True )
# 997 : Ragdoll_105.jpg 	(mask: True | bb: True )
# 998 : Ragdoll_116.jpg 	(mask: True | bb: True )
# 999 : Ragdoll_149.jpg 	(mask: True | bb: True )
# 1000 : Ragdoll_148.jpg 	(mask: True | bb: True )
# 1001 : Ragdoll_122.jpg 	(mask: True | bb: True )
# 1002 : Ragdoll_130.jpg 	(mask: True | bb: True )
# 1003 : Ragdoll_101.jpg 	(mask: True | bb: True )
# 1004 : Ragdoll_163.jpg 	(mask: True | bb: True )
# 1005 : Ragdoll_18.jpg 	(mask: True | bb: True )
# 1006 : Ragdoll_135.jpg 	(mask: True | bb: True )
# 1007 : Ragdoll_136.jpg 	(mask: True | bb: True )
# 1008 : Ragdoll_137.jpg 	(mask: True | bb: True )
# 1009 : Ragdoll_131.jpg 	(mask: True | bb: True )
# 1010 : Ragdoll_156.jpg 	(mask: True | bb: True )
# 1011 : Ragdoll_103.jpg 	(mask: True | bb: True )
# 1012 : Ragdoll_171.jpg 	(mask: True | bb: True )
# 1013 : Ragdoll_176.jpg 	(mask: True | bb: True )
# 1014 : Ragdoll_115.jpg 	(mask: True | bb: True )
# 1015 : Ragdoll_125.jpg 	(mask: True | bb: True )
# 1016 : Ragdoll_160.jpg 	(mask: True | bb: True )
# 1017 : Ragdoll_172.jpg 	(mask: True | bb: True )
# 1018 : Ragdoll_195.jpg 	(mask: True | bb: True )
# 1019 : Ragdoll_182.jpg 	(mask: True | bb: True )
# 1020 : Ragdoll_194.jpg 	(mask: True | bb: True )
# 1021 : Ragdoll_134.jpg 	(mask: True | bb: True )
# 1022 : Ragdoll_175.jpg 	(mask: True | bb: True )
# 1023 : Ragdoll_193.jpg 	(mask: True | bb: True )
# 1024 : Ragdoll_127.jpg 	(mask: True | bb: True )
# 1025 : Ragdoll_133.jpg 	(mask: True | bb: True )
# 1026 : Ragdoll_110.jpg 	(mask: True | bb: True )
# 1027 : Ragdoll_138.jpg 	(mask: True | bb: True )
# 1028 : Ragdoll_187.jpg 	(mask: True | bb: True )
# 1029 : Ragdoll_142.jpg 	(mask: True | bb: True )
# 1030 : Ragdoll_158.jpg 	(mask: True | bb: True )
# 1031 : Ragdoll_188.jpg 	(mask: True | bb: True )
# 1032 : Ragdoll_112.jpg 	(mask: True | bb: True )
# 1033 : Ragdoll_168.jpg 	(mask: True | bb: True )
# 1034 : Ragdoll_113.jpg 	(mask: True | bb: True )
# 1035 : Ragdoll_1.jpg 	(mask: True | bb: True )
# 1036 : Ragdoll_151.jpg 	(mask: True | bb: True )
# 1037 : Ragdoll_166.jpg 	(mask: True | bb: True )
# 1038 : Ragdoll_117.jpg 	(mask: True | bb: True )
# 1039 : Ragdoll_126.jpg 	(mask: True | bb: True )
# 1040 : Ragdoll_180.jpg 	(mask: True | bb: True )
# 1041 : Ragdoll_118.jpg 	(mask: True | bb: True )
# 1042 : Ragdoll_13.jpg 	(mask: True | bb: True )
# 1043 : Ragdoll_177.jpg 	(mask: True | bb: True )
# 1044 : Ragdoll_174.jpg 	(mask: True | bb: True )
# 1045 : Ragdoll_104.jpg 	(mask: True | bb: True )
# 1046 : Ragdoll_178.jpg 	(mask: True | bb: True )
# 1047 : Ragdoll_173.jpg 	(mask: True | bb: True )
# 1048 : Ragdoll_196.jpg 	(mask: True | bb: True )
# 1049 : Ragdoll_128.jpg 	(mask: True | bb: True )
# 1050 : Ragdoll_161.jpg 	(mask: True | bb: True )
# 1051 : Ragdoll_170.jpg 	(mask: True | bb: True )
# 1052 : Ragdoll_189.jpg 	(mask: True | bb: True )
# 1053 : Ragdoll_145.jpg 	(mask: True | bb: True )
# 1054 : Ragdoll_150.jpg 	(mask: True | bb: True )
# 1055 : Ragdoll_129.jpg 	(mask: True | bb: True )
# 1056 : Ragdoll_16.jpg 	(mask: True | bb: True )
# 1057 : Ragdoll_164.jpg 	(mask: True | bb: True )
# 1058 : Ragdoll_186.jpg 	(mask: True | bb: True )
# 1059 : Ragdoll_165.jpg 	(mask: True | bb: True )
# 1060 : Ragdoll_124.jpg 	(mask: True | bb: True )
# 1061 : Ragdoll_100.jpg 	(mask: True | bb: True )
# 1062 : Ragdoll_155.jpg 	(mask: True | bb: True )
# 1063 : Ragdoll_111.jpg 	(mask: True | bb: True )
# 1064 : Ragdoll_147.jpg 	(mask: True | bb: True )
# 1065 : Ragdoll_139.jpg 	(mask: True | bb: True )
# 1066 : Ragdoll_183.jpg 	(mask: True | bb: True )
# 1067 : Ragdoll_197.jpg 	(mask: True | bb: True )
# 1068 : Ragdoll_185.jpg 	(mask: True | bb: True )
# 1069 : Ragdoll_202.jpg 	(mask: True | bb: True )
# 1070 : Ragdoll_154.jpg 	(mask: True | bb: True )
# 1071 : Ragdoll_119.jpg 	(mask: True | bb: True )
# 1072 : Ragdoll_192.jpg 	(mask: True | bb: True )
# 1073 : Ragdoll_198.jpg 	(mask: True | bb: True )
# 1074 : Ragdoll_152.jpg 	(mask: True | bb: True )
# 1075 : Ragdoll_162.jpg 	(mask: True | bb: True )
# 1076 : Ragdoll_107.jpg 	(mask: True | bb: True )
# 1077 : Ragdoll_181.jpg 	(mask: True | bb: True )
# 1078 : Ragdoll_153.jpg 	(mask: True | bb: True )
# 1079 : Ragdoll_140.jpg 	(mask: True | bb: True )
# 1080 : Ragdoll_179.jpg 	(mask: True | bb: True )
# 1081 : Ragdoll_184.jpg 	(mask: True | bb: True )
# 1082 : Ragdoll_143.jpg 	(mask: True | bb: True )
# 1083 : Ragdoll_12.jpg 	(mask: True | bb: True )
# 1084 : Ragdoll_10.jpg 	(mask: True | bb: True )
# 1085 : Ragdoll_146.jpg 	(mask: True | bb: True )
# 1086 : Ragdoll_191.jpg 	(mask: True | bb: True )
# 1087 : Ragdoll_190.jpg 	(mask: True | bb: True )
# Reading files for label 'British_Shorthair'
# 1088 : British_Shorthair_117.jpg 	(mask: True | bb: True )
# 1089 : British_Shorthair_199.jpg 	(mask: True | bb: True )
# 1090 : British_Shorthair_129.jpg 	(mask: True | bb: True )
# 1091 : British_Shorthair_164.jpg 	(mask: True | bb: True )
# 1092 : British_Shorthair_128.jpg 	(mask: True | bb: True )
# 1093 : British_Shorthair_160.jpg 	(mask: True | bb: True )
# 1094 : British_Shorthair_190.jpg 	(mask: True | bb: True )
# 1095 : British_Shorthair_182.jpg 	(mask: True | bb: True )
# 1096 : British_Shorthair_100.jpg 	(mask: True | bb: True )
# 1097 : British_Shorthair_104.jpg 	(mask: True | bb: True )
# 1098 : British_Shorthair_18.jpg 	(mask: True | bb: True )
# 1099 : British_Shorthair_201.jpg 	(mask: True | bb: True )
# 1100 : British_Shorthair_169.jpg 	(mask: True | bb: True )
# 1101 : British_Shorthair_165.jpg 	(mask: True | bb: True )
# 1102 : British_Shorthair_134.jpg 	(mask: True | bb: True )
# 1103 : British_Shorthair_108.jpg 	(mask: True | bb: True )
# 1104 : British_Shorthair_167.jpg 	(mask: True | bb: True )
# 1105 : British_Shorthair_127.jpg 	(mask: True | bb: True )
# 1106 : British_Shorthair_204.jpg 	(mask: True | bb: True )
# 1107 : British_Shorthair_155.jpg 	(mask: True | bb: True )
# 1108 : British_Shorthair_145.jpg 	(mask: True | bb: True )
# 1109 : British_Shorthair_168.jpg 	(mask: True | bb: True )
# 1110 : British_Shorthair_180.jpg 	(mask: True | bb: True )
# 1111 : British_Shorthair_16.jpg 	(mask: True | bb: True )
# 1112 : British_Shorthair_156.jpg 	(mask: True | bb: True )
# 1113 : British_Shorthair_166.jpg 	(mask: True | bb: True )
# 1114 : British_Shorthair_161.jpg 	(mask: True | bb: True )
# 1115 : British_Shorthair_187.jpg 	(mask: True | bb: True )
# 1116 : British_Shorthair_195.jpg 	(mask: True | bb: True )
# 1117 : British_Shorthair_162.jpg 	(mask: True | bb: True )
# 1118 : British_Shorthair_183.jpg 	(mask: True | bb: True )
# 1119 : British_Shorthair_120.jpg 	(mask: True | bb: True )
# 1120 : British_Shorthair_116.jpg 	(mask: True | bb: True )
# 1121 : British_Shorthair_175.jpg 	(mask: True | bb: True )
# 1122 : British_Shorthair_163.jpg 	(mask: True | bb: True )
# 1123 : British_Shorthair_109.jpg 	(mask: True | bb: True )
# 1124 : British_Shorthair_10.jpg 	(mask: True | bb: True )
# 1125 : British_Shorthair_179.jpg 	(mask: True | bb: True )
# 1126 : British_Shorthair_174.jpg 	(mask: True | bb: True )
# 1127 : British_Shorthair_137.jpg 	(mask: True | bb: True )
# 1128 : British_Shorthair_126.jpg 	(mask: True | bb: True )
# 1129 : British_Shorthair_140.jpg 	(mask: True | bb: True )
# 1130 : British_Shorthair_133.jpg 	(mask: True | bb: True )
# 1131 : British_Shorthair_144.jpg 	(mask: True | bb: True )
# 1132 : British_Shorthair_157.jpg 	(mask: True | bb: True )
# 1133 : British_Shorthair_172.jpg 	(mask: True | bb: True )
# 1134 : British_Shorthair_114.jpg 	(mask: True | bb: True )
# 1135 : British_Shorthair_188.jpg 	(mask: True | bb: True )
# 1136 : British_Shorthair_196.jpg 	(mask: True | bb: True )
# 1137 : British_Shorthair_158.jpg 	(mask: True | bb: True )
# 1138 : British_Shorthair_200.jpg 	(mask: True | bb: True )
# 1139 : British_Shorthair_17.jpg 	(mask: True | bb: True )
# 1140 : British_Shorthair_205.jpg 	(mask: True | bb: True )
# 1141 : British_Shorthair_210.jpg 	(mask: True | bb: True )
# 1142 : British_Shorthair_185.jpg 	(mask: True | bb: True )
# 1143 : British_Shorthair_198.jpg 	(mask: True | bb: True )
# 1144 : British_Shorthair_159.jpg 	(mask: True | bb: True )
# 1145 : British_Shorthair_203.jpg 	(mask: True | bb: True )
# 1146 : British_Shorthair_154.jpg 	(mask: True | bb: True )
# 1147 : British_Shorthair_176.jpg 	(mask: True | bb: True )
# 1148 : British_Shorthair_123.jpg 	(mask: True | bb: True )
# 1149 : British_Shorthair_193.jpg 	(mask: True | bb: True )
# 1150 : British_Shorthair_115.jpg 	(mask: True | bb: True )
# 1151 : British_Shorthair_112.jpg 	(mask: True | bb: True )
# 1152 : British_Shorthair_124.jpg 	(mask: True | bb: True )
# 1153 : British_Shorthair_207.jpg 	(mask: True | bb: True )
# 1154 : British_Shorthair_118.jpg 	(mask: True | bb: True )
# 1155 : British_Shorthair_106.jpg 	(mask: True | bb: True )
# 1156 : British_Shorthair_209.jpg 	(mask: True | bb: True )
# 1157 : British_Shorthair_141.jpg 	(mask: True | bb: True )
# 1158 : British_Shorthair_153.jpg 	(mask: True | bb: True )
# 1159 : British_Shorthair_130.jpg 	(mask: True | bb: True )
# 1160 : British_Shorthair_113.jpg 	(mask: True | bb: True )
# 1161 : British_Shorthair_139.jpg 	(mask: True | bb: True )
# 1162 : British_Shorthair_105.jpg 	(mask: True | bb: True )
# 1163 : British_Shorthair_149.jpg 	(mask: True | bb: True )
# 1164 : British_Shorthair_103.jpg 	(mask: True | bb: True )
# 1165 : British_Shorthair_186.jpg 	(mask: True | bb: True )
# 1166 : British_Shorthair_178.jpg 	(mask: True | bb: True )
# 1167 : British_Shorthair_102.jpg 	(mask: True | bb: True )
# 1168 : British_Shorthair_189.jpg 	(mask: True | bb: True )
# 1169 : British_Shorthair_15.jpg 	(mask: True | bb: True )
# 1170 : British_Shorthair_119.jpg 	(mask: True | bb: True )
# 1171 : British_Shorthair_111.jpg 	(mask: True | bb: True )
# 1172 : British_Shorthair_173.jpg 	(mask: True | bb: True )
# 1173 : British_Shorthair_177.jpg 	(mask: True | bb: True )
# 1174 : British_Shorthair_181.jpg 	(mask: True | bb: True )
# 1175 : British_Shorthair_101.jpg 	(mask: True | bb: True )
# 1176 : British_Shorthair_151.jpg 	(mask: True | bb: True )
# 1177 : British_Shorthair_170.jpg 	(mask: True | bb: True )
# 1178 : British_Shorthair_184.jpg 	(mask: True | bb: True )
# 1179 : British_Shorthair_107.jpg 	(mask: True | bb: True )
# 1180 : British_Shorthair_125.jpg 	(mask: True | bb: True )
# 1181 : British_Shorthair_121.jpg 	(mask: True | bb: True )
# 1182 : British_Shorthair_197.jpg 	(mask: True | bb: True )
# 1183 : British_Shorthair_148.jpg 	(mask: True | bb: True )
# 1184 : British_Shorthair_122.jpg 	(mask: True | bb: True )
# 1185 : British_Shorthair_135.jpg 	(mask: True | bb: True )
# 1186 : British_Shorthair_136.jpg 	(mask: True | bb: True )
# 1187 : British_Shorthair_110.jpg 	(mask: True | bb: True )

# %%
#sample_id = 120;
#samples[sample_id].display();
#samples[sample_id].segmentation_regionbased();
#samples[sample_id].segmentation_edgebased();
#samples[sample_id].segmentation_colorclustering();

# %%
# Try the model.
fv = [];
labels = [];

for sample in samples:
    print("Extract features from:", sample.image_file);
    fv.append(sample.features());
    labels.append(sample.label);
    
# Rebalance.
oversampler = SMOTE();
(fv, labels) = oversampler.fit_resample(fv, labels);

# Scale.
scaler = RobustScaler();
fv = scaler.fit_transform(fv);
    
# Split the data.
x_train, x_test, y_train, y_test = train_test_split(fv, labels, test_size = 0.30, random_state = 64);

# Train.
dt = RandomForestClassifier();
dt.fit(x_train, y_train);

# Testing the model.
cv_scores = cross_val_score(dt, x_train, y_train, cv = 10);

print('Average Cross Validation Score from Training:', cv_scores.mean(), sep = '\n', end = '\n\n\n');

y_pred = dt.predict(x_test);
cm = confusion_matrix(y_test, y_pred);
cr = classification_report(y_test, y_pred);

print('Confusion Matrix:', cm, sep = '\n', end = '\n\n\n');
print('Missing classifications (if any):', set(y_test) - set(y_pred));
print('Test Statistics:', cr, sep = '\n', end = '\n\n\n');
print('Testing Accuracy:', accuracy_score(y_test, y_pred));
# Out:
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_117.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_103.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_155.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_143.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_150.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_165.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_16.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_118.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_183.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_123.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_159.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_158.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_142.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_114.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_125.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_140.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_138.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_181.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_127.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_161.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_122.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_174.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_149.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_136.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_121.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_141.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_13.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_102.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_145.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_133.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_176.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_18.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_192.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_167.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_106.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_119.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_191.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_175.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_14.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_120.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_151.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_109.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_190.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_184.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_11.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_157.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_116.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_182.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_193.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_111.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_195.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_169.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_128.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_10.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_164.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_126.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_179.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_124.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_152.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_146.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_173.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_180.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_160.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_110.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_134.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_130.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_153.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_168.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_197.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_166.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_196.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_107.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_135.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_178.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_185.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_12.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_172.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_115.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_15.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_144.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_19.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_105.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_139.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_129.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_17.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_148.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_154.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_177.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_1.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_132.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_156.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_170.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_131.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_100.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_137.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_112.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_108.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_101.jpg
# Extract features from: /home/cva/catifier/training_data/Abyssinian/Abyssinian_113.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_203.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_195.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_116.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_112.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_138.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_153.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_202.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_185.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_186.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_179.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_148.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_108.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_189.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_204.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_142.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_197.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_128.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_187.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_156.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_183.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_126.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_17.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_165.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_198.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_166.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_115.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_172.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_1.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_196.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_151.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_18.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_117.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_139.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_131.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_144.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_176.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_155.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_152.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_193.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_122.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_121.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_127.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_177.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_164.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_114.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_171.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_150.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_111.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_162.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_201.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_178.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_107.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_191.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_188.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_143.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_180.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_141.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_110.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_170.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_192.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_173.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_12.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_124.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_133.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_160.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_132.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_174.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_175.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_104.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_125.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_194.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_14.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_184.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_182.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_102.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_146.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_11.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_199.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_205.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_157.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_19.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_103.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_129.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_105.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_169.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_134.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_168.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_181.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_15.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_136.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_200.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_158.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_137.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_206.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_145.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_159.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_190.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_130.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_119.jpg
# Extract features from: /home/cva/catifier/training_data/Sphynx/Sphynx_167.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_108.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_171.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_11.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_136.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_100.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_149.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_130.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_107.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_138.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_168.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_18.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_15.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_147.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_120.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_131.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_16.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_173.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_178.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_128.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_113.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_143.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_161.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_101.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_104.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_12.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_133.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_134.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_122.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_153.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_111.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_109.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_126.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_190.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_154.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_114.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_180.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_165.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_182.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_144.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_146.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_188.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_151.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_197.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_103.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_116.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_192.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_115.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_119.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_110.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_163.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_164.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_196.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_172.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_185.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_157.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_174.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_187.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_148.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_118.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_10.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_179.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_176.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_112.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_195.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_124.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_181.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_183.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_142.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_141.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_102.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_125.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_127.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_129.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_13.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_184.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_140.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_170.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_160.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_175.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_152.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_121.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_189.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_123.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_194.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_132.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_193.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_106.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_150.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_162.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_117.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_105.jpg
# Extract features from: /home/cva/catifier/training_data/Egyptian_Mau/Egyptian_Mau_155.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_129.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_217.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_20.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_136.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_173.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_194.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_175.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_15.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_108.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_132.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_107.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_186.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_158.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_185.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_197.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_188.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_121.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_187.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_170.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_152.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_138.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_105.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_122.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_133.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_123.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_104.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_144.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_150.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_128.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_153.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_149.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_112.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_181.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_125.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_201.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_118.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_18.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_169.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_13.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_156.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_162.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_160.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_134.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_101.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_143.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_172.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_19.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_120.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_166.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_135.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_16.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_183.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_100.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_189.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_137.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_206.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_180.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_190.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_159.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_191.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_193.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_102.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_202.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_184.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_111.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_147.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_195.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_161.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_116.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_165.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_182.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_196.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_155.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_200.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_176.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_168.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_106.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_171.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_12.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_139.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_213.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_103.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_145.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_114.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_140.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_174.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_126.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_164.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_17.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_115.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_131.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_10.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_179.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_141.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_192.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_1.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_163.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_14.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_117.jpg
# Extract features from: /home/cva/catifier/training_data/Persian/Persian_11.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_164.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_133.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_143.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_19.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_112.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_202.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_182.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_127.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_129.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_145.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_184.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_158.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_169.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_116.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_172.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_150.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_175.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_189.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_136.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_161.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_199.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_104.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_14.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_165.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_207.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_146.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_194.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_130.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_139.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_142.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_154.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_100.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_188.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_206.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_205.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_186.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_120.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_152.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_109.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_128.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_140.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_148.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_187.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_181.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_171.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_159.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_119.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_108.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_201.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_17.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_196.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_178.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_170.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_102.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_163.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_18.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_110.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_149.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_131.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_115.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_173.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_122.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_138.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_113.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_101.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_204.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_180.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_183.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_179.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_103.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_141.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_195.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_106.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_126.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_135.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_147.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_155.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_137.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_176.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_156.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_193.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_200.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_208.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_191.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_167.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_114.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_160.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_198.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_185.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_162.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_125.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_168.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_144.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_111.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_203.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_151.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_153.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_117.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_174.jpg
# Extract features from: /home/cva/catifier/training_data/Siamese/Siamese_157.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_187.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_118.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_128.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_123.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_121.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_127.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_102.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_130.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_163.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_107.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_154.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_122.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_157.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_177.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_131.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_160.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_10.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_143.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_17.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_119.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_171.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_173.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_129.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_168.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_184.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_137.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_180.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_181.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_176.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_175.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_124.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_166.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_144.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_149.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_152.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_169.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_140.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_179.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_100.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_109.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_112.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_138.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_103.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_147.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_156.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_132.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_11.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_185.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_141.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_146.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_161.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_170.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_155.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_158.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_105.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_14.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_106.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_135.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_178.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_165.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_18.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_15.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_189.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_174.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_162.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_183.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_12.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_159.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_186.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_172.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_164.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_126.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_188.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_16.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_113.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_153.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_13.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_136.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_190.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_110.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_151.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_134.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_145.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_116.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_142.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_139.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_148.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_133.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_125.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_108.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_111.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_104.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_115.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_150.jpg
# Extract features from: /home/cva/catifier/training_data/Birman/Birman_182.jpg
# ...
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_168.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_113.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_1.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_151.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_166.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_117.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_126.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_180.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_118.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_13.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_177.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_174.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_104.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_178.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_173.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_196.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_128.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_161.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_170.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_189.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_145.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_150.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_129.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_16.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_164.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_186.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_165.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_124.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_100.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_155.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_111.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_147.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_139.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_183.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_197.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_185.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_202.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_154.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_119.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_192.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_198.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_152.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_162.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_107.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_181.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_153.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_140.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_179.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_184.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_143.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_12.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_10.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_146.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_191.jpg
# Extract features from: /home/cva/catifier/training_data/Ragdoll/Ragdoll_190.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_117.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_199.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_129.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_164.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_128.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_160.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_190.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_182.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_100.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_104.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_18.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_201.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_169.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_165.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_134.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_108.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_167.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_127.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_204.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_155.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_145.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_168.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_180.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_16.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_156.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_166.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_161.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_187.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_195.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_162.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_183.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_120.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_116.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_175.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_163.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_109.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_10.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_179.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_174.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_137.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_126.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_140.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_133.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_144.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_157.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_172.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_114.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_188.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_196.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_158.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_200.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_17.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_205.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_210.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_185.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_198.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_159.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_203.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_154.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_176.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_123.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_193.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_115.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_112.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_124.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_207.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_118.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_106.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_209.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_141.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_153.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_130.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_113.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_139.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_105.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_149.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_103.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_186.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_178.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_102.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_189.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_15.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_119.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_111.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_173.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_177.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_181.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_101.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_151.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_170.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_184.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_107.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_125.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_121.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_197.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_148.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_122.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_135.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_136.jpg
# Extract features from: /home/cva/catifier/training_data/British_Shorthair/British_Shorthair_110.jpg
# Average Cross Validation Score from Training:
# 0.3547619047619047
#
#
# Confusion Matrix:
# [[10  6  1  1  1  1  3  1  0  2  1  3]
#  [ 4 10  2  3  0  0  5  2  0  0  1  0]
#  [ 0  1  6  1  2  4  1  2  6  1  5  1]
#  [ 0  0  0 24  1  0  1  0  0  1  0  0]
#  [ 0  2  1  1 15  1  5  3  3  4  0  0]
#  [ 1  1  2  0  0  7  0  0  0  5  7  2]
#  [ 5  7  2  1  0  0  4  4  2  1  3  1]
#  [ 4  1  0  0  1  0  1  9  4  2  1  3]
#  [ 3  0  4  0  1  4  0  5  6  0  5  3]
#  [ 1  1  0  2  8  4  1  1  1 11  0  0]
#  [ 0  5  7  1  0  3  7  1  3  0  5  3]
#  [10  1  3  0  2  3  2  1  1  1  2  8]]
#
#
# Missing classifications (if any): set()
# Test Statistics:
#                    precision    recall  f1-score   support
#
#        Abyssinian       0.26      0.33      0.29        30
#            Bengal       0.29      0.37      0.32        27
#            Birman       0.21      0.20      0.21        30
#            Bombay       0.71      0.89      0.79        27
# British_Shorthair       0.48      0.43      0.45        35
#      Egyptian_Mau       0.26      0.28      0.27        25
#        Maine_Coon       0.13      0.13      0.13        30
#           Persian       0.31      0.35      0.33        26
#           Ragdoll       0.23      0.19      0.21        31
#      Russian_Blue       0.39      0.37      0.38        30
#           Siamese       0.17      0.14      0.15        35
#            Sphynx       0.33      0.24      0.28        34
#
#          accuracy                           0.32       360
#         macro avg       0.31      0.33      0.32       360
#      weighted avg       0.31      0.32      0.31       360
#
#
#
# Testing Accuracy: 0.3194444444444444
